# %% [markdown]
# # 1. Acquiring, preprocessing, and analyzing the data

# %% [markdown]
# Importing libraries that are necessary for the project:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#sns.set()
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# First we load in the data and take a look

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/ionosphere/ionosphere.data'
ionosphere = pd.read_csv(url)
ionosphere.head()
# Out:
#    1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0  1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1  1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2  1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3  1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4  1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
#
#    0.03760  ...  -0.51171  0.41078  -0.46168  0.21266  -0.34090  0.42267  \
# 0 -0.04549  ...  -0.26569 -0.20468  -0.18401 -0.19040  -0.11593 -0.16626
# 1  0.01198  ...  -0.40220  0.58984  -0.22145  0.43100  -0.17365  0.60436
# 2  0.00000  ...   0.90695  0.51613   1.00000  1.00000  -0.20099  0.25682
# 3 -0.16399  ...  -0.65158  0.13290  -0.53206  0.02431  -0.62197 -0.05707
# 4  0.06637  ...  -0.01535 -0.03240   0.09223 -0.07859   0.00732  0.00000
#
#    -0.54487  0.18641  -0.45300  g
# 0  -0.06288 -0.13738  -0.02447  b
# 1  -0.24180  0.56045  -0.38238  g
# 2   1.00000 -0.32382   1.00000  b
# 3  -0.59573 -0.04608  -0.65697  g
# 4   0.00000 -0.00039   0.12011  b
#
# [5 rows x 35 columns]

# %% [markdown]
# Note that the dataset is continuous.

# %% [markdown]
# In the following section the columns are assigned reasonable names for the sake of easily identifying them in the future:

# %%
clmns = []
pulse_no1 = 0

for i in range(0, ionosphere.shape[1] - 1):
    
    if (i%2 == 0):
        pulse_no1 = pulse_no1 + 1
        pulse_no2 = 1
    else:
        pulse_no2 = 2
    clmns.append('Pulse ' + str(pulse_no1) + '.' + str(pulse_no2))

clmns.append('Structure detected')

# %%
ionosphere.columns = clmns
ionosphere.head()
# Out:
#    Pulse 1.1  Pulse 1.2  Pulse 2.1  Pulse 2.2  Pulse 3.1  Pulse 3.2  \
# 0          1          0    1.00000   -0.18829    0.93035   -0.36156
# 1          1          0    1.00000   -0.03365    1.00000    0.00485
# 2          1          0    1.00000   -0.45161    1.00000    1.00000
# 3          1          0    1.00000   -0.02401    0.94140    0.06531
# 4          1          0    0.02337   -0.00592   -0.09924   -0.11949
#
#    Pulse 4.1  Pulse 4.2  Pulse 5.1  Pulse 5.2  ...  Pulse 13.2  Pulse 14.1  \
# 0   -0.10868   -0.93597    1.00000   -0.04549  ...    -0.26569    -0.20468
# 1    1.00000   -0.12062    0.88965    0.01198  ...    -0.40220     0.58984
# 2    0.71216   -1.00000    0.00000    0.00000  ...     0.90695     0.51613
# 3    0.92106   -0.23255    0.77152   -0.16399  ...    -0.65158     0.13290
# 4   -0.00763   -0.11824    0.14706    0.06637  ...    -0.01535    -0.03240
#
#    Pulse 14.2  Pulse 15.1  Pulse 15.2  Pulse 16.1  Pulse 16.2  Pulse 17.1  \
# 0    -0.18401    -0.19040    -0.11593    -0.16626    -0.06288    -0.13738
# 1    -0.22145     0.43100    -0.17365     0.60436    -0.24180     0.56045
# 2     1.00000     1.00000    -0.20099     0.25682     1.00000    -0.32382
# 3    -0.53206     0.02431    -0.62197    -0.05707    -0.59573    -0.04608
# 4     0.09223    -0.07859     0.00732     0.00000     0.00000    -0.00039
#
#    Pulse 17.2  Structure detected
# 0    -0.02447                   b
# 1    -0.38238                   g
# 2     1.00000                   b
# 3    -0.65697                   g
# 4     0.12011                   b
#
# [5 rows x 35 columns]

# %% [markdown]
# Let's do little bit of processing of different variables that might be interesting to look at. First, we look at the datatype of each column:

# %%
ionosphere.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 35 columns):
# Pulse 1.1             350 non-null int64
# Pulse 1.2             350 non-null int64
# Pulse 2.1             350 non-null float64
# Pulse 2.2             350 non-null float64
# Pulse 3.1             350 non-null float64
# Pulse 3.2             350 non-null float64
# Pulse 4.1             350 non-null float64
# Pulse 4.2             350 non-null float64
# Pulse 5.1             350 non-null float64
# Pulse 5.2             350 non-null float64
# Pulse 6.1             350 non-null float64
# Pulse 6.2             350 non-null float64
# Pulse 7.1             350 non-null float64
# Pulse 7.2             350 non-null float64
# Pulse 8.1             350 non-null float64
# Pulse 8.2             350 non-null float64
# Pulse 9.1             350 non-null float64
# Pulse 9.2             350 non-null float64
# Pulse 10.1            350 non-null float64
# Pulse 10.2            350 non-null float64
# Pulse 11.1            350 non-null float64
# Pulse 11.2            350 non-null float64
# Pulse 12.1            350 non-null float64
# Pulse 12.2            350 non-null float64
# Pulse 13.1            350 non-null float64
# Pulse 13.2            350 non-null float64
# Pulse 14.1            350 non-null float64
# Pulse 14.2            350 non-null float64
# Pulse 15.1            350 non-null float64
# Pulse 15.2            350 non-null float64
# Pulse 16.1            350 non-null float64
# Pulse 16.2            350 non-null float64
# Pulse 17.1            350 non-null float64
# Pulse 17.2            350 non-null float64
# Structure detected    350 non-null object
# dtypes: float64(32), int64(2), object(1)
# memory usage: 95.8+ KB

# %% [markdown]
# Column Pulse 1.1 looks suspiciosly uniform. We check whether all entries of Pulse 1.1 are 1:

# %%
ionosphere.isin([1]).sum(axis = 0)[:1] #checking whether all entries of Pulse 1.1 are 1
# Out:
# Pulse 1.1    312
# dtype: int64

# %% [markdown]
# Not all entries of Pulse 1.1 are 1.  However, column Pulse 1.2 looks suspiciosly uniform as well. We check whether all entries of Pulse 1.2 are 0:

# %%
ionosphere.isin([0]).sum(axis = 0)[1:2] #checking whether all entries of Pulse 1.2 are 0
# Out:
# Pulse 1.2    350
# dtype: int64

# %% [markdown]
# We see that column Pulse 1.2 is constant and can be dropped:

# %%
ionosphere = ionosphere.drop(['Pulse 1.2'], axis = 1)
ionosphere
# Out:
#      Pulse 1.1  Pulse 2.1  Pulse 2.2  Pulse 3.1  Pulse 3.2  Pulse 4.1  \
# 0            1    1.00000   -0.18829    0.93035   -0.36156   -0.10868
# 1            1    1.00000   -0.03365    1.00000    0.00485    1.00000
# 2            1    1.00000   -0.45161    1.00000    1.00000    0.71216
# 3            1    1.00000   -0.02401    0.94140    0.06531    0.92106
# 4            1    0.02337   -0.00592   -0.09924   -0.11949   -0.00763
# ..         ...        ...        ...        ...        ...        ...
# 345          1    0.83508    0.08298    0.73739   -0.14706    0.84349
# 346          1    0.95113    0.00419    0.95183   -0.02723    0.93438
# 347          1    0.94701   -0.00034    0.93207   -0.03227    0.95177
# 348          1    0.90608   -0.01657    0.98122   -0.01989    0.95691
# 349          1    0.84710    0.13533    0.73638   -0.06151    0.87873
#
#      Pulse 4.2  Pulse 5.1  Pulse 5.2  Pulse 6.1  ...  Pulse 13.2  Pulse 14.1  \
# 0     -0.93597    1.00000   -0.04549    0.50874  ...    -0.26569    -0.20468
# 1     -0.12062    0.88965    0.01198    0.73082  ...    -0.40220     0.58984
# 2     -1.00000    0.00000    0.00000    0.00000  ...     0.90695     0.51613
# 3     -0.23255    0.77152   -0.16399    0.52798  ...    -0.65158     0.13290
# 4     -0.11824    0.14706    0.06637    0.03786  ...    -0.01535    -0.03240
# ..         ...        ...        ...        ...  ...         ...         ...
# 345   -0.05567    0.90441   -0.04622    0.89391  ...    -0.04202     0.83479
# 346   -0.01920    0.94590    0.01606    0.96510  ...     0.01361     0.93522
# 347   -0.03431    0.95584    0.02446    0.94124  ...     0.03193     0.92489
# 348   -0.03646    0.85746    0.00110    0.89724  ...    -0.02099     0.89147
# 349    0.08260    0.88928   -0.09139    0.78735  ...    -0.15114     0.81147
#
#      Pulse 14.2  Pulse 15.1  Pulse 15.2  Pulse 16.1  Pulse 16.2  Pulse 17.1  \
# 0      -0.18401    -0.19040    -0.11593    -0.16626    -0.06288    -0.13738
# 1      -0.22145     0.43100    -0.17365     0.60436    -0.24180     0.56045
# 2       1.00000     1.00000    -0.20099     0.25682     1.00000    -0.32382
# 3      -0.53206     0.02431    -0.62197    -0.05707    -0.59573    -0.04608
# 4       0.09223    -0.07859     0.00732     0.00000     0.00000    -0.00039
# ..          ...         ...         ...         ...         ...         ...
# 345     0.00123     1.00000     0.12815     0.86660    -0.10714     0.90546
# 346     0.04925     0.93159     0.08168     0.94066    -0.00035     0.91483
# 347     0.02542     0.92120     0.02242     0.92459     0.00442     0.92697
# 348    -0.07760     0.82983    -0.17238     0.96022    -0.03757     0.87403
# 349    -0.04822     0.78207    -0.00703     0.75747    -0.06678     0.85764
#
#      Pulse 17.2  Structure detected
# 0      -0.02447                   b
# 1      -0.38238                   g
# 2       1.00000                   b
# 3      -0.65697                   g
# 4       0.12011                   b
# ..          ...                 ...
# 345    -0.04307                   g
# 346     0.04712                   g
# 347    -0.00577                   g
# 348    -0.16243                   g
# 349    -0.06151                   g
#
# [350 rows x 34 columns]

# %% [markdown]
# Just in case, the datatype inconsistensy is analyzed in a different way as well:

# %%
# Detecting dtype inconsistency
print('Columns with data type inconsistensy:')
n_weird_columns = 0
for col in ionosphere.columns:
    weird = (ionosphere[[col]].applymap(type) != ionosphere[[col]].iloc[0].apply(type)).any(axis=1)
    if len(ionosphere[weird]) > 0:
        print(col)
        n_weird_columns = n_weird_columns + 1
if (n_weird_columns == 0):
    print('None')
# Out:
# Columns with data type inconsistensy:
# None

# %% [markdown]
# The last column has the 'object' type. It is transformed into numerical values with 0 corresponding to 'b' and 1 corresponding to 'g' as follows:

# %%
for i in range(len(ionosphere['Structure detected'])):
    y_i = ionosphere['Structure detected'][i]
    if (y_i == 'b'):
        ionosphere['Structure detected'][i] = 0
    elif (y_i == 'g'):
        ionosphere['Structure detected'][i] = 1

ionosphere = ionosphere.astype({'Structure detected': 'int64'})
ionosphere.head()
# Out:
# /Users/Nick/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/Nick/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Pulse 1.1  Pulse 2.1  Pulse 2.2  Pulse 3.1  Pulse 3.2  Pulse 4.1  \
# 0          1    1.00000   -0.18829    0.93035   -0.36156   -0.10868
# 1          1    1.00000   -0.03365    1.00000    0.00485    1.00000
# 2          1    1.00000   -0.45161    1.00000    1.00000    0.71216
# 3          1    1.00000   -0.02401    0.94140    0.06531    0.92106
# 4          1    0.02337   -0.00592   -0.09924   -0.11949   -0.00763
#
#    Pulse 4.2  Pulse 5.1  Pulse 5.2  Pulse 6.1  ...  Pulse 13.2  Pulse 14.1  \
# 0   -0.93597    1.00000   -0.04549    0.50874  ...    -0.26569    -0.20468
# 1   -0.12062    0.88965    0.01198    0.73082  ...    -0.40220     0.58984
# 2   -1.00000    0.00000    0.00000    0.00000  ...     0.90695     0.51613
# 3   -0.23255    0.77152   -0.16399    0.52798  ...    -0.65158     0.13290
# 4   -0.11824    0.14706    0.06637    0.03786  ...    -0.01535    -0.03240
#
#    Pulse 14.2  Pulse 15.1  Pulse 15.2  Pulse 16.1  Pulse 16.2  Pulse 17.1  \
# 0    -0.18401    -0.19040    -0.11593    -0.16626    -0.06288    -0.13738
# 1    -0.22145     0.43100    -0.17365     0.60436    -0.24180     0.56045
# 2     1.00000     1.00000    -0.20099     0.25682     1.00000    -0.32382
# 3    -0.53206     0.02431    -0.62197    -0.05707    -0.59573    -0.04608
# 4     0.09223    -0.07859     0.00732     0.00000     0.00000    -0.00039
#
#    Pulse 17.2  Structure detected
# 0    -0.02447                   0
# 1    -0.38238                   1
# 2     1.00000                   0
# 3    -0.65697                   1
# 4     0.12011                   0
#
# [5 rows x 34 columns]

# %%
ionosphere.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 34 columns):
# Pulse 1.1             350 non-null int64
# Pulse 2.1             350 non-null float64
# Pulse 2.2             350 non-null float64
# Pulse 3.1             350 non-null float64
# Pulse 3.2             350 non-null float64
# Pulse 4.1             350 non-null float64
# Pulse 4.2             350 non-null float64
# Pulse 5.1             350 non-null float64
# Pulse 5.2             350 non-null float64
# Pulse 6.1             350 non-null float64
# Pulse 6.2             350 non-null float64
# Pulse 7.1             350 non-null float64
# Pulse 7.2             350 non-null float64
# Pulse 8.1             350 non-null float64
# Pulse 8.2             350 non-null float64
# Pulse 9.1             350 non-null float64
# Pulse 9.2             350 non-null float64
# Pulse 10.1            350 non-null float64
# Pulse 10.2            350 non-null float64
# Pulse 11.1            350 non-null float64
# Pulse 11.2            350 non-null float64
# Pulse 12.1            350 non-null float64
# Pulse 12.2            350 non-null float64
# Pulse 13.1            350 non-null float64
# Pulse 13.2            350 non-null float64
# Pulse 14.1            350 non-null float64
# Pulse 14.2            350 non-null float64
# Pulse 15.1            350 non-null float64
# Pulse 15.2            350 non-null float64
# Pulse 16.1            350 non-null float64
# Pulse 16.2            350 non-null float64
# Pulse 17.1            350 non-null float64
# Pulse 17.2            350 non-null float64
# Structure detected    350 non-null int64
# dtypes: float64(32), int64(2)
# memory usage: 93.1 KB

# %% [markdown]
# Splitting the data into the test and train datasets:

# %%
msk = np.random.rand(len(ionosphere)) < 0.8
train = ionosphere[msk]
test = ionosphere[~msk]
print('Train entries: ' + str(len(train)))
print('Test entries: ' + str(len(test)))
# Out:
# Train entries: 268
# Test entries: 82

# %% [markdown]
# Checking how much of the train data are good and bad:

# %%
X_train = train.iloc[:, :-1] # feature values
y_train = train.iloc[:, -1] # target values

print('Number of good entries: ' + str(train.loc[y_train == 1].shape[0]))
print('Number of bad entries: ' + str(train.loc[y_train == 0].shape[0]))
# Out:
# Number of good entries: 173
# Number of bad entries: 95

# %% [markdown]
# We can take a look at the prior probability of 'good' entries:

# %%
prior = train.loc[y_train == 1].shape[0] / (train.loc[y_train == 1].shape[0] + train.loc[y_train == 0].shape[0])
prior
# Out:
# 0.6455223880597015

# %% [markdown]
# We can plot some data to see potential dependencies. In this section dependencies between Pulses i.1 and i.2 are plotted for $i = 2, 3, ..., 17$ ($i=1$ is obscluded since Pulse 1.2 is constant and dropped).

# %%
pulse_no1 = 2 # the Pulse we start with

for i in range(1, train.shape[1] - 1):
    
    if (i%2 == 0):
        pulse_no1 = pulse_no1 + 1
        pulse_no2 = 1
    else:
        pulse_no2 = 2
        xlabel = 'Pulse ' + str(pulse_no1) + '.' + str(1)
        ylabel = 'Pulse ' + str(pulse_no1) + '.' + str(2)
        
        fig, ax = plt.subplots()
        ax2 = train.plot.scatter(x=xlabel, y=ylabel, c = 'Structure detected', colormap='viridis', ax = ax)
    #clmns.append('Pulse ' + str(pulse_no1) + '.' + str(pulse_no2))


#plt.show()
#ionosphere.reset_index().plot(x="Pulse 2.1", y='Pulse 2.2', c = 'Structure detected', ax = (0, 0), colormap='viridis', kind = 'scatter')
#ionosphere.reset_index().plot(x="Pulse 3.1", y='Pulse 3.2', c = 'Structure detected', ax = (0, 1), colormap='viridis', kind = 'scatter')
#ionosphere.diff().plot(ax=axes[r,c]).scatter(x='Pulse 2.1', y='Pulse 2.2', c = 'Structure detected', colormap='viridis')
    
#ax1 = ionosphere.diff().plot.scatter(x='Pulse 2.1', y='Pulse 2.2', c = 'Structure detected', colormap='viridis')

# %% [markdown]
# # 2. Implementing the models

# %% [markdown]
# ## 2.1. Implementing logistic regression

# %% [markdown]
# A class for logistic regression with gradient descent:

# %%
class Logistic_Regression:
    def __init__(self,
                 lr = 0.01, #learning rate of the gradient descent method
                 eps = 1e-2, # termination condition of the gradient descent method
                ):
        self.lr = lr
        self.eps = eps
        
    # Implementing the logistic function
    def __logistic_function(self, x):
        return 1/(1 + np.exp(-x))
    
    # Implementing the cost function
    def __cost(self,
               w, # N
               X_train, # N x D
               y_train, # N
              ):
        z = np.dot(X_train, w) # N x 1
        J = np.mean(y_train * np.log1p(np.exp(-z)) + (1 - y_train) * np.log1p(np.exp(z)))
        return J
    
    # Implementing the gradient function
    def __gradient(self,
                   w, # N
                   X_train, # N x D
                   y_train, # N
                  ):
        N = y_train.size
        z = np.dot(X_train, w) # N x 1
        yh = self.__logistic_function(z)
        return np.dot(X_train.T, (yh - y_train)) / N
    
    def __GradientDescent(self,
                          X_train, # N x D
                          y_train, # N
                          lr, #learning rate
                          eps # termination condition is used if n_iterations == 0
                         ):
        #N, D = X.shape
        N = X_train.shape[0]
        
        intercept = np.ones((N, 1))
        X_train = np.concatenate((intercept, X_train), axis=1)
        
        D = X_train.shape[1]
        
        w = np.zeros(D)
        g = np.inf
        
        n_iterations = 0 # just for counting the number of iterations
        while (np.linalg.norm(g) > eps):
            g = self.__gradient(w, X_train, y_train)
            w = w - lr * g

            n_iterations += 1

        print('Number of iterations of the gradient descent:', n_iterations)
        
        return w
    
    # Implementing the fit function
    def fit(self,
            X_train, # N x D
            y_train # N
            ):
        
        w = self.__GradientDescent(X_train, y_train, self.lr, self.eps)
        
        return w
    
    # Implementing the predict function
    def predict (self,
                 X_test,
                 w,
                threshold = 0.5
                ):
        intercept = np.ones((X_test.shape[0], 1))
        X_test = np.concatenate((intercept, X_test), axis=1)

        return self.__logistic_function(np.dot(X_test, w)) >= threshold
    
    # Function for checking the algorithm accuracy
    def evaluate_acc(self,
                    predicted_values,
                    true_values
                    ):
        check = []
        i = 0
        correct = 0
        incorrect = 0
        for y_i in true_values:
            if ((y_i == 1) and (predicted_values[i] == True)):
                check.append([True])
                correct += 1
            elif ((y_i == 0) and (predicted_values[i] == False)):
                check.append([True])
                correct += 1
            else:
                check.append([False])
                incorrect += 1  
            i += 1
        
        accuracy = correct/(correct + incorrect)
        print('Correct classifications:', correct)
        print('Incorrect classifications:', incorrect)
        print('Accuracy of the logistic regression:', correct/(correct + incorrect))
        
        return accuracy

# %% [markdown]
# Essentially the same class but instead of the termiantion condition $\epsilon$ the number of iterations $n_{iterations}$ is used

# %%
class Logistic_Regression_Iter:
    def __init__(self,
                 lr = 0.01, #learning rate of the gradient descent method
                 n_iterations = 1e-2, # number of iterations of the gradient descent method
                ):
        self.lr = lr
        self.n_iterations = n_iterations
        
    # Implementing the logistic function
    def __logistic_function(self, x):
        return 1/(1 + np.exp(-x))
    
    # Implementing the cost function
    def __cost(self,
               w, # N
               X_train, # N x D
               y_train, # N
              ):
        z = np.dot(X_train, w) # N x 1
        J = np.mean(y_train * np.log1p(np.exp(-z)) + (1 - y_train) * np.log1p(np.exp(z)))
        return J
    
    # Implementing the gradient function
    def __gradient(self,
                   w, # N
                   X_train, # N x D
                   y_train, # N
                  ):
        N = y_train.size
        z = np.dot(X_train, w) # N x 1
        yh = self.__logistic_function(z)
        return np.dot(X_train.T, (yh - y_train)) / N
    
    def __GradientDescent(self,
                          X_train, # N x D
                          y_train, # N
                          lr, #learning rate
                          n_iterations # termination condition
                         ):
        #N, D = X.shape
        N = X_train.shape[0]
        
        intercept = np.ones((N, 1))
        X_train = np.concatenate((intercept, X_train), axis=1)
        
        D = X_train.shape[1]
        
        w = np.zeros(D)
        g = np.inf
        
        n = 0 # just for counting the number of iterations
        while (n_iterations > n):
            g = self.__gradient(w, X_train, y_train)
            w = w - lr * g

            n += 1

        #print('Number of iterations of the gradient descent:', n)
        
        return w
    
    # Implementing the fit function
    def fit(self,
            X_train, # N x D
            y_train # N
            ):
        
        w = self.__GradientDescent(X_train, y_train, self.lr, self.n_iterations)
        
        return w
    
    # Implementing the predict function
    def predict (self,
                 X_test,
                 w,
                threshold = 0.5
                ):
        intercept = np.ones((X_test.shape[0], 1))
        X_test = np.concatenate((intercept, X_test), axis=1)

        return self.__logistic_function(np.dot(X_test, w)) >= threshold
    
    # Function for checking the algorithm accuracy
    def evaluate_acc(self,
                    predicted_values,
                    true_values
                    ):
        check = []
        i = 0
        correct = 0
        incorrect = 0
        for y_i in true_values:
            if ((y_i == 1) and (predicted_values[i] == True)):
                check.append([True])
                correct += 1
            elif ((y_i == 0) and (predicted_values[i] == False)):
                check.append([True])
                correct += 1
            else:
                check.append([False])
                incorrect += 1  
            i += 1
        
        accuracy = correct/(correct + incorrect)
        print('Correct classifications:', correct)
        print('Incorrect classifications:', incorrect)
        print('Accuracy of the logistic regression:', correct/(correct + incorrect))
        
        return accuracy

# %% [markdown]
# Setting up the logistic regression:

# %%
LR = Logistic_Regression()

# %% [markdown]
# Running the fit function:

# %%
# %time w = LR.fit(X_train, y_train)
w
# Out:
# Number of iterations of the gradient descent: 41583
# CPU times: user 18.5 s, sys: 44.3 ms, total: 18.5 s
# Wall time: 18.5 s
# array([-4.06439842,  1.85665146,  2.09615676,  1.39412827,  1.63481404,
#         2.48232199,  0.67237681,  1.53129346,  1.05896664,  0.48403001,
#        -1.94097243, -1.20400704, -0.1801467 ,  1.70692342,  1.03536945,
#         0.74272882,  1.01174655, -0.78818122, -0.45457011, -0.3908486 ,
#         0.5521462 , -2.13982602,  1.35200884,  1.00912515,  0.09271861,
#         1.07732606, -2.66743802, -0.04577543,  0.70727206,  0.86448029,
#         1.0862714 ,  0.24538649, -0.24716212, -2.03484973])

# %% [markdown]
# Separating the feature and the target values in the test dataset:

# %%
X_test = test.iloc[:, :-1] # feature values
y_test = test.iloc[:, -1] # target values

# %% [markdown]
# Running the predict function:

# %%
pred = LR.predict(X_test, w)

# %% [markdown]
# Checking how much of the test dataset was predicted correctly:

# %%
accuracy = LR.evaluate_acc(pred, y_test)
# Out:
# Correct classifications: 71
# Incorrect classifications: 11
# Accuracy of the logistic regression: 0.8658536585365854

# %% [markdown]
# ## 2.2. Implementing Naïve Bayes

# %%
class GaussianNaiveBayes:
    def __init__(self):
        pass
    
    # The fit function returns the mean, the standard deviation, and the logariphmic prior probability
    def fit(self,
            X_train, # N x D
            y_train, # N x C
           ):
        N = y_train.shape[0]
        c = 0
        C = 1
        D = X_train.shape[1]
        self.mu, self.s = np.zeros((C, D)), np.zeros((C, D)) #mean and standard deviation

        inds = np.nonzero(y_train[:])[0] # indeces of non-zero classes
        self.mu = np.mean(X_train.iloc[inds, :])
        self.s = np.std(X_train.iloc[inds, :])
        self.log_prior = np.log(np.mean(y_train))
        
        return [self.mu, self.s, self.log_prior]
    
    def predict(self,
                X_test, # N_test x
               ):
        log_likelihood = - np.sum( np.log(self.s) + .5*(((X_test - self.mu)/self.s)**2), 1)
        
        pred = self.log_prior + log_likelihood #N_test x C
        
        # Converting to boolean...
        pred = (pred > 0)
        # ... and to binary:
        pred = pred.astype(int)
        return pred #N_test x C
    
    # Function for checking the algorithm accuracy
    def evaluate_acc(self,
                    predicted_values,
                    true_values
                    ):
        check = []
        i = 0 # a counter for retreiving information from predicted target values
        correct = 0
        incorrect = 0
        for y_i in true_values:
            if ((y_i == 1) and (predicted_values.iloc[i] == 1)):
                check.append([True])
                correct += 1
            elif ((y_i == 0) and (predicted_values.iloc[i] == 0)):
                check.append([True])
                correct += 1
            else:
                check.append([False])
                incorrect += 1  
            i += 1

        accuracy = correct/(correct + incorrect)
        print('Correct classifications:', correct)
        print('Incorrect classifications:', incorrect)
        print('Accuracy of the naive Bayes:', correct/(correct + incorrect))
        
        return accuracy

# %%
GNB = GaussianNaiveBayes()

# %%
mu, s, log_prior = GNB.fit(X_train, y_train)
# Out:
# /Users/Nick/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:61: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#   return bound(*args, **kwds)

# %%
pred = GNB.predict(X_test)
pred
# Out:
# /Users/Nick/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:856: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0      0
# 5      1
# 6      0
# 7      1
# 10     0
#       ..
# 332    1
# 336    0
# 340    1
# 348    1
# 349    1
# Length: 82, dtype: int64

# %%
accuracy = GNB.evaluate_acc(pred, y_test)
# Out:
# Correct classifications: 57
# Incorrect classifications: 25
# Accuracy of the naive Bayes: 0.6951219512195121

# %% [markdown]
# ## 2.3. Implementing $k$-fold cross-validation

# %%
def Linear_Regression_k_Fold_Cross_Validation(dataset, # the initial dataset
                                              k, # number of folds
                                              lr = 0.01, #learning rate of the gradient descent method
                                              eps = 1e-2, # termination condition of the gradient descent method
                                             ):
    print('Logistic regression:')
    
    logistic_regression_accuracy = []
    
    # Splitting the dataset into folds: 
    folds = np.array_split(dataset, k)
    
    for i in range(k):
        print('Fold', i + 1)
        test = folds[i] # the test dataset is the i-th fold
        
        train = folds.copy() # consider the train dataset to be a copy of all folds
        del train[i] # removing the i-th fold
        train = pd.concat(train, sort = False)
        
        # Train dataset:
        X_train = train.iloc[:, :-1] # feature values
        y_train = train.iloc[:, -1] # target values
        
        # Test dataset:
        X_test = test.iloc[:, :-1] # feature values
        y_test = test.iloc[:, -1] # target values
        
        # Logistic regression
        
        LR = Logistic_Regression(lr = lr)
        w = LR.fit(X_train, y_train)
        pred = LR.predict(X_test, w)
        logistic_regression_accuracy.append(LR.evaluate_acc(pred, y_test))
        
        print('----------------------------------------')
        
    mu_LR = np.mean(logistic_regression_accuracy)
    std_LR = np.std(logistic_regression_accuracy)
    
    
    print('Logistic regression mean:', mu_LR)
    print('Logistic regression standard deviation:', std_LR)
    
    return mu_LR, std_LR

# %%
def Linear_Regression_Iter_k_Fold_Cross_Validation(dataset, # the initial dataset
                                              k, # number of folds
                                              lr = 0.01, #learning rate of the gradient descent method
                                              n_iterations = 300 #number of iterations
                                             ):
    print('Logistic regression:')
    
    logistic_regression_accuracy = []
    
    # Splitting the dataset into folds: 
    folds = np.array_split(dataset, k)
    
    for i in range(k):
        print('Fold', i + 1)
        test = folds[i] # the test dataset is the i-th fold
        
        train = folds.copy() # consider the train dataset to be a copy of all folds
        del train[i] # removing the i-th fold
        train = pd.concat(train, sort = False)
        
        # Train dataset:
        X_train = train.iloc[:, :-1] # feature values
        y_train = train.iloc[:, -1] # target values
        
        # Test dataset:
        X_test = test.iloc[:, :-1] # feature values
        y_test = test.iloc[:, -1] # target values
        
        # Logistic regression
        
        LR = Logistic_Regression_Iter(lr = lr, n_iterations = n_iterations)
        w = LR.fit(X_train, y_train)
        pred = LR.predict(X_test, w)
        logistic_regression_accuracy.append(LR.evaluate_acc(pred, y_test))
        
        print('----------------------------------------')
        
    mu_LR = np.mean(logistic_regression_accuracy)
    std_LR = np.std(logistic_regression_accuracy)
    
    
    print('Logistic regression mean:', mu_LR)
    print('Logistic regression standard deviation:', std_LR)
    
    return mu_LR, std_LR

# %%
def Naive_Bayes_k_Fold_Cross_Validation(dataset, # the initial dataset
                                        k # number of folds
                                       ):
    print('Naive Bayes')
    naive_bayes_accuracy = []
    
    # Splitting the dataset into folds: 
    folds = np.array_split(dataset, k)
    
    for i in range(k):
        print('Fold', i + 1)
        test = folds[i] # the test dataset is the i-th fold
        
        train = folds.copy() # consider the train dataset to be a copy of all folds
        del train[i] # removing the i-th fold
        train = pd.concat(train, sort = False)
        
        # Train dataset:
        X_train = train.iloc[:, :-1] # feature values
        y_train = train.iloc[:, -1] # target values
        
        # Test dataset:
        X_test = test.iloc[:, :-1] # feature values
        y_test = test.iloc[:, -1] # target values
        
        # Naive Bayes
        print('Naive Bayes')
        GNB = GaussianNaiveBayes()
        mu, s, log_prior = GNB.fit(X_train, y_train)
        pred = GNB.predict(X_test)
        naive_bayes_accuracy.append(GNB.evaluate_acc(pred, y_test))
        print('----------------------------------------')
    
    mu_NB = np.mean(naive_bayes_accuracy)
    std_NB = np.std(naive_bayes_accuracy)
    
    print('Naive Bayes mean:', mu_NB)
    print('Naive Bayes standard deviation:', std_NB)
    
    return mu_NB, std_NB

# %% [markdown]
# # 3. Running the experiments

# %% [markdown]
# ## 3.1. $k$-fold cross-validation test

# %% [markdown]
# First we run $k$-fold cross-validation for logistic regresstion with $k=5$:

# %%
# %time mu_LR, std_LR = Linear_Regression_k_Fold_Cross_Validation(ionosphere, k = 5, lr = 0.01, eps = 1e-2)
# Out:
# Logistic regression:
# Fold 1
# Number of iterations of the gradient descent: 35306
# Correct classifications: 53
# Incorrect classifications: 17
# Accuracy of the logistic regression: 0.7571428571428571
# ----------------------------------------
# Fold 2
# Number of iterations of the gradient descent: 36799
# Correct classifications: 54
# Incorrect classifications: 16
# Accuracy of the logistic regression: 0.7714285714285715
# ----------------------------------------
# Fold 3
# Number of iterations of the gradient descent: 33677
# Correct classifications: 57
# Incorrect classifications: 13
# Accuracy of the logistic regression: 0.8142857142857143
# ----------------------------------------
# Fold 4
# Number of iterations of the gradient descent: 32505
# Correct classifications: 64
# Incorrect classifications: 6
# Accuracy of the logistic regression: 0.9142857142857143
# ----------------------------------------
# Fold 5
# Number of iterations of the gradient descent: 32869
# Correct classifications: 67
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.9571428571428572
# ----------------------------------------
# Logistic regression mean: 0.8428571428571427
# Logistic regression standard deviation: 0.07928249671720919
# CPU times: user 1min 12s, sys: 497 ms, total: 1min 13s
# Wall time: 1min 14s

# %% [markdown]
# We do the same for naive Bayes:

# %%
# %time mu_NB, std_NB = Naive_Bayes_k_Fold_Cross_Validation(ionosphere, 5)
# Out:
# Naive Bayes
# Fold 1
# Naive Bayes
# Correct classifications: 59
# Incorrect classifications: 11
# Accuracy of the naive Bayes: 0.8428571428571429
# ----------------------------------------
# Fold 2
# Naive Bayes
# Correct classifications: 54
# Incorrect classifications: 16
# Accuracy of the naive Bayes: 0.7714285714285715
# ----------------------------------------
# Fold 3
# Naive Bayes
# Correct classifications: 52
# Incorrect classifications: 18
# Accuracy of the naive Bayes: 0.7428571428571429
# ----------------------------------------
# Fold 4
# Naive Bayes
# Correct classifications: 55
# Incorrect classifications: 15
# Accuracy of the naive Bayes: 0.7857142857142857
# ----------------------------------------
# Fold 5
# Naive Bayes
# Correct classifications: 45
# Incorrect classifications: 25
# Accuracy of the naive Bayes: 0.6428571428571429
# ----------------------------------------
# Naive Bayes mean: 0.7571428571428571
# Naive Bayes standard deviation: 0.0657763681898362
# CPU times: user 392 ms, sys: 32.6 ms, total: 424 ms
# Wall time: 574 ms

# %% [markdown]
# Note that accuracy of the logistic regression is higher than of naive Bayes which comes at a cost of slower computation.

# %% [markdown]
# ## 3.2. Tet of different learning rates for the gradient descent

# %% [markdown]
# Here we test learning rates $10^{-3}, 10^{-2}, 10^{-1}, 10^{0}$ while keeping the termination criteria $\epsilon = 0.01$ the same. Note that for the learning rate greater than $1$ the gradient descent overshoots and does not converge (try fold $4$ at your own risk!) and for the learning rate lower than $10^{-3}$ the computation is too slow and seems like an overkill.

# %%
learning_rates = []
stds = []
mus = []
times = []

for i in range(4):
    learning_rates.append(10**-i)
    print('Learning rate:',10**-i)
    
    start_time = time.time()
    mu_LR, std_LR = Linear_Regression_k_Fold_Cross_Validation(ionosphere, 5, lr = learning_rates[i])
    time_ellapsed = time.time() - start_time
    
    print('Time ellapsed:', time_ellapsed)
    times.append(time_ellapsed)
    
    mus.append(mu_LR)
    stds.append(std_LR)
# Out:
# Learning rate: 1
# Logistic regression:
# Fold 1
# Number of iterations of the gradient descent: 354
# Correct classifications: 53
# Incorrect classifications: 17
# Accuracy of the logistic regression: 0.7571428571428571
# ----------------------------------------
# Fold 2
# Number of iterations of the gradient descent: 368
# Correct classifications: 54
# Incorrect classifications: 16
# Accuracy of the logistic regression: 0.7714285714285715
# ----------------------------------------
# Fold 3
# Number of iterations of the gradient descent: 337
# Correct classifications: 57
# Incorrect classifications: 13
# Accuracy of the logistic regression: 0.8142857142857143
# ----------------------------------------
# Fold 4
# Number of iterations of the gradient descent: 326
# Correct classifications: 64
# Incorrect classifications: 6
# Accuracy of the logistic regression: 0.9142857142857143
# ----------------------------------------
# Fold 5
# Number of iterations of the gradient descent: 329
# Correct classifications: 67
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.9571428571428572
# ----------------------------------------
# Logistic regression mean: 0.8428571428571427
# Logistic regression standard deviation: 0.07928249671720919
# Time ellapsed: 1.5423340797424316
# Learning rate: 0.1
# Logistic regression:
# Fold 1
# Number of iterations of the gradient descent: 3531
# Correct classifications: 53
# Incorrect classifications: 17
# Accuracy of the logistic regression: 0.7571428571428571
# ----------------------------------------
# Fold 2
# Number of iterations of the gradient descent: 3680
# Correct classifications: 54
# Incorrect classifications: 16
# Accuracy of the logistic regression: 0.7714285714285715
# ----------------------------------------
# Fold 3
# Number of iterations of the gradient descent: 3368
# Correct classifications: 57
# Incorrect classifications: 13
# Accuracy of the logistic regression: 0.8142857142857143
# ----------------------------------------
# Fold 4
# Number of iterations of the gradient descent: 3251
# Correct classifications: 64
# Incorrect classifications: 6
# Accuracy of the logistic regression: 0.9142857142857143
# ----------------------------------------
# Fold 5
# Number of iterations of the gradient descent: 3287
# Correct classifications: 67
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.9571428571428572
# ----------------------------------------
# Logistic regression mean: 0.8428571428571427
# Logistic regression standard deviation: 0.07928249671720919
# Time ellapsed: 11.843585014343262
# Learning rate: 0.01
# Logistic regression:
# Fold 1
# Number of iterations of the gradient descent: 35306
# Correct classifications: 53
# Incorrect classifications: 17
# Accuracy of the logistic regression: 0.7571428571428571
# ----------------------------------------
# Fold 2
# Number of iterations of the gradient descent: 36799
# Correct classifications: 54
# Incorrect classifications: 16
# Accuracy of the logistic regression: 0.7714285714285715
# ----------------------------------------
# Fold 3
# Number of iterations of the gradient descent: 33677
# Correct classifications: 57
# Incorrect classifications: 13
# Accuracy of the logistic regression: 0.8142857142857143
# ----------------------------------------
# Fold 4
# Number of iterations of the gradient descent: 32505
# Correct classifications: 64
# Incorrect classifications: 6
# Accuracy of the logistic regression: 0.9142857142857143
# ----------------------------------------
# Fold 5
# Number of iterations of the gradient descent: 32869
# Correct classifications: 67
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.9571428571428572
# ----------------------------------------
# Logistic regression mean: 0.8428571428571427
# Logistic regression standard deviation: 0.07928249671720919
# Time ellapsed: 103.91504406929016
# Learning rate: 0.001
# Logistic regression:
# Fold 1
# Number of iterations of the gradient descent: 353053
# Correct classifications: 53
# Incorrect classifications: 17
# Accuracy of the logistic regression: 0.7571428571428571
# ----------------------------------------
# Fold 2
# Number of iterations of the gradient descent: 367988
# Correct classifications: 54
# Incorrect classifications: 16
# Accuracy of the logistic regression: 0.7714285714285715
# ----------------------------------------
# Fold 3
# Number of iterations of the gradient descent: 336761
# Correct classifications: 57
# Incorrect classifications: 13
# Accuracy of the logistic regression: 0.8142857142857143
# ----------------------------------------
# Fold 4
# Number of iterations of the gradient descent: 325043
# Correct classifications: 64
# Incorrect classifications: 6
# Accuracy of the logistic regression: 0.9142857142857143
# ----------------------------------------
# Fold 5
# Number of iterations of the gradient descent: 328686
# Correct classifications: 67
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.9571428571428572
# ----------------------------------------
# Logistic regression mean: 0.8428571428571427
# Logistic regression standard deviation: 0.07928249671720919
# Time ellapsed: 776.2886478900909

# %%
mus
# Out:
# [0.8428571428571427,
#  0.8428571428571427,
#  0.8428571428571427,
#  0.8428571428571427]

# %%
stds
# Out:
# [0.07928249671720919,
#  0.07928249671720919,
#  0.07928249671720919,
#  0.07928249671720919]

# %%
plt.plot(learning_rates, times)
plt.xlabel('Learning rate')
plt.ylabel('Time elapsed, s')
plt.xscale(value = 'log')
plt.grid()
plt.title('Log scale plot of the time required to perform the logistic regression depending on its learning rate')
plt.show()

# %% [markdown]
# We see that the results do not depend on the choise of the learning rate but setting the learning rate closer to zero results in a significant increase of time.

# %% [markdown]
# Now we check how does the accuracy depends of the number of iteratins of the gradient descent method used in logistic regression. We set the maximum $n_{iterations}=10^3$.

# %%
stds = []
mus = []
times = []

n_iterations = range(1, 1000)

for n in n_iterations:
    print('n_iterations =', n)
    start_time = time.time()
    mu_LR, std_LR = Linear_Regression_Iter_k_Fold_Cross_Validation(ionosphere,
                                                              k = 5,
                                                              n_iterations = n)
    time_ellapsed = time.time() - start_time
    
    print('Time ellapsed:', time_ellapsed)
    times.append(time_ellapsed)
    
    mus.append(mu_LR)
    stds.append(std_LR)
    
    print('----------------------------------------')
# Out:
# n_iterations = 1
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.04902911186218262
# ----------------------------------------
# n_iterations = 2
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.0573430061340332
# ----------------------------------------
# n_iterations = 3
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.05126786231994629
# ----------------------------------------
# n_iterations = 4
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.044261932373046875
# ----------------------------------------
# n_iterations = 5
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.07208991050720215
# ----------------------------------------
# n_iterations = 6
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.05251193046569824
# ----------------------------------------
# n_iterations = 7
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.05280113220214844
# ----------------------------------------
# n_iterations = 8
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.06508231163024902
# ----------------------------------------
# n_iterations = 9
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.07999706268310547
# ----------------------------------------
# n_iterations = 10
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.06157422065734863
# ----------------------------------------
# n_iterations = 11
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.08679318428039551
# ----------------------------------------
# n_iterations = 12
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.10139083862304688
# ----------------------------------------
# n_iterations = 13
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.10842227935791016
# ----------------------------------------
# n_iterations = 14
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.09541010856628418
# ----------------------------------------
# n_iterations = 15
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.07926082611083984
# ----------------------------------------
# n_iterations = 16
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.08942079544067383
# ----------------------------------------
# n_iterations = 17
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.07989096641540527
# ----------------------------------------
# n_iterations = 18
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.09251093864440918
# ----------------------------------------
# n_iterations = 19
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.08227825164794922
# ----------------------------------------
# n_iterations = 20
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 37
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.5285714285714286
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6685714285714286
# Logistic regression standard deviation: 0.18236541025409084
# Time ellapsed: 0.08508014678955078
# ----------------------------------------
# n_iterations = 21
# Logistic regression:
# Fold 1
# Correct classifications: 40
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.5714285714285714
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6714285714285715
# Logistic regression standard deviation: 0.18024926052100007
# Time ellapsed: 0.10065197944641113
# ----------------------------------------
# n_iterations = 22
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.09387803077697754
# ----------------------------------------
# n_iterations = 23
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.11562228202819824
# ----------------------------------------
# n_iterations = 24
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.10084080696105957
# ----------------------------------------
# n_iterations = 25
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.17231297492980957
# ----------------------------------------
# n_iterations = 26
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.1646871566772461
# ----------------------------------------
# n_iterations = 27
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.156599760055542
# ----------------------------------------
# n_iterations = 28
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.1051483154296875
# ----------------------------------------
# n_iterations = 29
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.160722017288208
# ----------------------------------------
# n_iterations = 30
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.13701725006103516
# ----------------------------------------
# n_iterations = 31
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.13230490684509277
# ----------------------------------------
# n_iterations = 32
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.18102073669433594
# ----------------------------------------
# n_iterations = 33
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.161665678024292
# ----------------------------------------
# n_iterations = 34
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.2666780948638916
# ----------------------------------------
# n_iterations = 35
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.12459897994995117
# ----------------------------------------
# n_iterations = 36
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.1464240550994873
# ----------------------------------------
# n_iterations = 37
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.13248491287231445
# ----------------------------------------
# n_iterations = 38
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.15198588371276855
# ----------------------------------------
# n_iterations = 39
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.15652108192443848
# ----------------------------------------
# n_iterations = 40
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.15211796760559082
# ----------------------------------------
# n_iterations = 41
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.2764708995819092
# ----------------------------------------
# n_iterations = 42
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.34686803817749023
# ----------------------------------------
# n_iterations = 43
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.3568999767303467
# ----------------------------------------
# n_iterations = 44
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.32729506492614746
# ----------------------------------------
# n_iterations = 45
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.24989700317382812
# ----------------------------------------
# n_iterations = 46
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.24896883964538574
# ----------------------------------------
# n_iterations = 47
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# Correct classifications: 38
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.5428571428571428
# ----------------------------------------
# Fold 4
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 5
# Correct classifications: 70
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.6742857142857143
# Logistic regression standard deviation: 0.1787484836527663
# Time ellapsed: 0.19623303413391113
# ----------------------------------------
# n_iterations = 48
# Logistic regression:
# Fold 1
# Correct classifications: 41
# Incorrect classifications: 29
# Accuracy of the logistic regression: 0.5857142857142857
# ----------------------------------------
# Fold 2
# Correct classifications: 36
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.5142857142857142
# ----------------------------------------
# Fold 3
# ...
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.997159004211426
# ----------------------------------------
# n_iterations = 985
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.9110519886016846
# ----------------------------------------
# n_iterations = 986
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.818305015563965
# ----------------------------------------
# n_iterations = 987
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.6816041469573975
# ----------------------------------------
# n_iterations = 988
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.7197229862213135
# ----------------------------------------
# n_iterations = 989
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.6774680614471436
# ----------------------------------------
# n_iterations = 990
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.68914794921875
# ----------------------------------------
# n_iterations = 991
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.681088924407959
# ----------------------------------------
# n_iterations = 992
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.626512289047241
# ----------------------------------------
# n_iterations = 993
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.6063339710235596
# ----------------------------------------
# n_iterations = 994
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.6234209537506104
# ----------------------------------------
# n_iterations = 995
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.585843086242676
# ----------------------------------------
# n_iterations = 996
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.6638050079345703
# ----------------------------------------
# n_iterations = 997
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.615213632583618
# ----------------------------------------
# n_iterations = 998
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.6344830989837646
# ----------------------------------------
# n_iterations = 999
# Logistic regression:
# Fold 1
# Correct classifications: 49
# Incorrect classifications: 21
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Fold 2
# Correct classifications: 47
# Incorrect classifications: 23
# Accuracy of the logistic regression: 0.6714285714285714
# ----------------------------------------
# Fold 3
# Correct classifications: 51
# Incorrect classifications: 19
# Accuracy of the logistic regression: 0.7285714285714285
# ----------------------------------------
# Fold 4
# Correct classifications: 61
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.8714285714285714
# ----------------------------------------
# Fold 5
# Correct classifications: 69
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9857142857142858
# ----------------------------------------
# Logistic regression mean: 0.7914285714285715
# Logistic regression standard deviation: 0.11904380946285524
# Time ellapsed: 2.6729259490966797
# ----------------------------------------

# %% [markdown]
# We can obtain error as $error = 1 - \mu$.

# %%
error = []
for m in mus:
    error.append(1 - m)

# %%
#plt.plot(n_iterations, mus)
plt.xlabel('Number of iterations')
plt.ylabel('Error')
#plt.xscale(value = 'log')
plt.errorbar(n_iterations, error, stds, color = 'red', ecolor = 'blue', linewidth = 5)
plt.grid()
plt.title('Accuracy of logistic regression depending on the number of iterations in the gradient descent\n with the mean in red and the standard deviation in blue')
plt.show()

# %% [markdown]
# Note that the mean of accuracy grows with the number of iterations. Note that its standard deviation shrinks.

# %%
plt.plot(n_iterations, times)
plt.xlabel('Learning rate')
plt.ylabel('Time elapsed, s')
plt.grid()
plt.title('Time required to perform the logistic regression depending on the number of iterations of its gradient descent')
plt.show()

# %% [markdown]
# Note that the time grows linearly except for some cases where the algorithm seems to overshoot.

# %% [markdown]
# We can get the dependece of the error rate of both learning methods on the test/train split ratio.

# %%
split_ratio = []
mus = []
stds = []

for i in range(1, 100):
    print('Logistic regression:')
    
    logistic_regression_accuracy = []
    
    split_ratio.append(i * 0.01)
    print('Train-to-test split ratio:', split_ratio[i - 1])
    
    # Splitting the dataset into folds:
    for k in range(5):
        msk = np.random.rand(len(ionosphere)) < split_ratio[i - 1]
        train = ionosphere[msk]
        test = ionosphere[~msk]
        
        # Train dataset:
        X_train = train.iloc[:, :-1] # feature values
        y_train = train.iloc[:, -1] # target values
        
        # Test dataset:
        X_test = test.iloc[:, :-1] # feature values
        y_test = test.iloc[:, -1] # target values
        
        # Logistic regression
        
        LR = Logistic_Regression()
        w = LR.fit(X_train, y_train)
        pred = LR.predict(X_test, w)
        logistic_regression_accuracy.append(LR.evaluate_acc(pred, y_test))
        
        print('----------------------------------------')
        
    mu_LR = np.mean(logistic_regression_accuracy)
    std_LR = np.std(logistic_regression_accuracy)
    
    print('Logistic regression mean:', mu_LR)
    print('Logistic regression standard deviation:', std_LR)
    
    mus.append(mu_LR)
    stds.append(std_LR)
# Out:
# Logistic regression:
# Train-to-test split ratio: 0.01
# Number of iterations of the gradient descent: 7995
# Correct classifications: 240
# Incorrect classifications: 106
# Accuracy of the logistic regression: 0.6936416184971098
# ----------------------------------------
# Number of iterations of the gradient descent: 13539
# Correct classifications: 251
# Incorrect classifications: 90
# Accuracy of the logistic regression: 0.7360703812316716
# ----------------------------------------
# Number of iterations of the gradient descent: 4782
# Correct classifications: 140
# Incorrect classifications: 207
# Accuracy of the logistic regression: 0.4034582132564842
# ----------------------------------------
# Number of iterations of the gradient descent: 3292
# Correct classifications: 231
# Incorrect classifications: 117
# Accuracy of the logistic regression: 0.6637931034482759
# ----------------------------------------
# Number of iterations of the gradient descent: 3785
# Correct classifications: 224
# Incorrect classifications: 116
# Accuracy of the logistic regression: 0.6588235294117647
# ----------------------------------------
# Logistic regression mean: 0.6311573691690612
# Logistic regression standard deviation: 0.11712252959354805
# Logistic regression:
# Train-to-test split ratio: 0.02
# Number of iterations of the gradient descent: 10697
# Correct classifications: 208
# Incorrect classifications: 138
# Accuracy of the logistic regression: 0.6011560693641619
# ----------------------------------------
# Number of iterations of the gradient descent: 16317
# Correct classifications: 164
# Incorrect classifications: 179
# Accuracy of the logistic regression: 0.478134110787172
# ----------------------------------------
# Number of iterations of the gradient descent: 3059
# Correct classifications: 228
# Incorrect classifications: 120
# Accuracy of the logistic regression: 0.6551724137931034
# ----------------------------------------
# Number of iterations of the gradient descent: 13067
# Correct classifications: 281
# Incorrect classifications: 63
# Accuracy of the logistic regression: 0.8168604651162791
# ----------------------------------------
# Number of iterations of the gradient descent: 6013
# Correct classifications: 235
# Incorrect classifications: 108
# Accuracy of the logistic regression: 0.685131195335277
# ----------------------------------------
# Logistic regression mean: 0.6472908508791987
# Logistic regression standard deviation: 0.11044481478008318
# Logistic regression:
# Train-to-test split ratio: 0.03
# Number of iterations of the gradient descent: 12428
# Correct classifications: 242
# Incorrect classifications: 96
# Accuracy of the logistic regression: 0.7159763313609467
# ----------------------------------------
# Number of iterations of the gradient descent: 20135
# Correct classifications: 246
# Incorrect classifications: 93
# Accuracy of the logistic regression: 0.7256637168141593
# ----------------------------------------
# Number of iterations of the gradient descent: 11087
# Correct classifications: 266
# Incorrect classifications: 77
# Accuracy of the logistic regression: 0.7755102040816326
# ----------------------------------------
# Number of iterations of the gradient descent: 5798
# Correct classifications: 211
# Incorrect classifications: 125
# Accuracy of the logistic regression: 0.6279761904761905
# ----------------------------------------
# Number of iterations of the gradient descent: 11915
# Correct classifications: 241
# Incorrect classifications: 101
# Accuracy of the logistic regression: 0.7046783625730995
# ----------------------------------------
# Logistic regression mean: 0.7099609610612057
# Logistic regression standard deviation: 0.04760015322096145
# Logistic regression:
# Train-to-test split ratio: 0.04
# Number of iterations of the gradient descent: 24331
# Correct classifications: 254
# Incorrect classifications: 80
# Accuracy of the logistic regression: 0.7604790419161677
# ----------------------------------------
# Number of iterations of the gradient descent: 14357
# Correct classifications: 268
# Incorrect classifications: 68
# Accuracy of the logistic regression: 0.7976190476190477
# ----------------------------------------
# Number of iterations of the gradient descent: 9560
# Correct classifications: 241
# Incorrect classifications: 94
# Accuracy of the logistic regression: 0.7194029850746269
# ----------------------------------------
# Number of iterations of the gradient descent: 25259
# Correct classifications: 264
# Incorrect classifications: 72
# Accuracy of the logistic regression: 0.7857142857142857
# ----------------------------------------
# Number of iterations of the gradient descent: 16052
# Correct classifications: 274
# Incorrect classifications: 63
# Accuracy of the logistic regression: 0.8130563798219584
# ----------------------------------------
# Logistic regression mean: 0.7752543480292172
# Logistic regression standard deviation: 0.03279106008166862
# Logistic regression:
# Train-to-test split ratio: 0.05
# Number of iterations of the gradient descent: 3618
# Correct classifications: 226
# Incorrect classifications: 117
# Accuracy of the logistic regression: 0.6588921282798834
# ----------------------------------------
# Number of iterations of the gradient descent: 19951
# Correct classifications: 270
# Incorrect classifications: 64
# Accuracy of the logistic regression: 0.8083832335329342
# ----------------------------------------
# Number of iterations of the gradient descent: 49691
# Correct classifications: 260
# Incorrect classifications: 62
# Accuracy of the logistic regression: 0.8074534161490683
# ----------------------------------------
# Number of iterations of the gradient descent: 45928
# Correct classifications: 266
# Incorrect classifications: 63
# Accuracy of the logistic regression: 0.8085106382978723
# ----------------------------------------
# Number of iterations of the gradient descent: 15221
# Correct classifications: 261
# Incorrect classifications: 73
# Accuracy of the logistic regression: 0.781437125748503
# ----------------------------------------
# Logistic regression mean: 0.7729353084016523
# Logistic regression standard deviation: 0.05795133663046177
# Logistic regression:
# Train-to-test split ratio: 0.06
# Number of iterations of the gradient descent: 13043
# Correct classifications: 272
# Incorrect classifications: 60
# Accuracy of the logistic regression: 0.8192771084337349
# ----------------------------------------
# Number of iterations of the gradient descent: 22240
# Correct classifications: 256
# Incorrect classifications: 68
# Accuracy of the logistic regression: 0.7901234567901234
# ----------------------------------------
# Number of iterations of the gradient descent: 24040
# Correct classifications: 271
# Incorrect classifications: 62
# Accuracy of the logistic regression: 0.8138138138138138
# ----------------------------------------
# Number of iterations of the gradient descent: 21651
# Correct classifications: 247
# Incorrect classifications: 81
# Accuracy of the logistic regression: 0.7530487804878049
# ----------------------------------------
# Number of iterations of the gradient descent: 28066
# Correct classifications: 265
# Incorrect classifications: 62
# Accuracy of the logistic regression: 0.8103975535168195
# ----------------------------------------
# Logistic regression mean: 0.7973321426084593
# Logistic regression standard deviation: 0.024235978564665847
# Logistic regression:
# Train-to-test split ratio: 0.07
# Number of iterations of the gradient descent: 18433
# Correct classifications: 266
# Incorrect classifications: 62
# Accuracy of the logistic regression: 0.8109756097560976
# ----------------------------------------
# Number of iterations of the gradient descent: 21143
# Correct classifications: 267
# Incorrect classifications: 53
# Accuracy of the logistic regression: 0.834375
# ----------------------------------------
# Number of iterations of the gradient descent: 37858
# Correct classifications: 276
# Incorrect classifications: 48
# Accuracy of the logistic regression: 0.8518518518518519
# ----------------------------------------
# Number of iterations of the gradient descent: 31163
# Correct classifications: 264
# Incorrect classifications: 61
# Accuracy of the logistic regression: 0.8123076923076923
# ----------------------------------------
# Number of iterations of the gradient descent: 26838
# Correct classifications: 223
# Incorrect classifications: 107
# Accuracy of the logistic regression: 0.6757575757575758
# ----------------------------------------
# Logistic regression mean: 0.7970535459346435
# Logistic regression standard deviation: 0.06250595249856386
# Logistic regression:
# Train-to-test split ratio: 0.08
# Number of iterations of the gradient descent: 23826
# Correct classifications: 246
# Incorrect classifications: 72
# Accuracy of the logistic regression: 0.7735849056603774
# ----------------------------------------
# Number of iterations of the gradient descent: 20112
# Correct classifications: 250
# Incorrect classifications: 70
# Accuracy of the logistic regression: 0.78125
# ----------------------------------------
# Number of iterations of the gradient descent: 18420
# Correct classifications: 250
# Incorrect classifications: 59
# Accuracy of the logistic regression: 0.8090614886731392
# ----------------------------------------
# Number of iterations of the gradient descent: 15952
# Correct classifications: 251
# Incorrect classifications: 66
# Accuracy of the logistic regression: 0.7917981072555205
# ----------------------------------------
# Number of iterations of the gradient descent: 9507
# Correct classifications: 234
# Incorrect classifications: 89
# Accuracy of the logistic regression: 0.7244582043343654
# ----------------------------------------
# Logistic regression mean: 0.7760305411846804
# Logistic regression standard deviation: 0.02839925859394411
# Logistic regression:
# Train-to-test split ratio: 0.09
# Number of iterations of the gradient descent: 33118
# Correct classifications: 269
# Incorrect classifications: 50
# Accuracy of the logistic regression: 0.8432601880877743
# ----------------------------------------
# Number of iterations of the gradient descent: 23280
# Correct classifications: 227
# Incorrect classifications: 90
# Accuracy of the logistic regression: 0.7160883280757098
# ----------------------------------------
# Number of iterations of the gradient descent: 24860
# Correct classifications: 261
# Incorrect classifications: 52
# Accuracy of the logistic regression: 0.8338658146964856
# ----------------------------------------
# Number of iterations of the gradient descent: 34172
# Correct classifications: 268
# Incorrect classifications: 51
# Accuracy of the logistic regression: 0.8401253918495298
# ----------------------------------------
# Number of iterations of the gradient descent: 21874
# Correct classifications: 257
# Incorrect classifications: 69
# Accuracy of the logistic regression: 0.7883435582822086
# ----------------------------------------
# Logistic regression mean: 0.8043366561983415
# Logistic regression standard deviation: 0.04839709233675414
# Logistic regression:
# Train-to-test split ratio: 0.1
# Number of iterations of the gradient descent: 30356
# Correct classifications: 250
# Incorrect classifications: 52
# Accuracy of the logistic regression: 0.8278145695364238
# ----------------------------------------
# Number of iterations of the gradient descent: 17671
# Correct classifications: 258
# Incorrect classifications: 60
# Accuracy of the logistic regression: 0.8113207547169812
# ----------------------------------------
# Number of iterations of the gradient descent: 20964
# Correct classifications: 260
# Incorrect classifications: 58
# Accuracy of the logistic regression: 0.8176100628930818
# ----------------------------------------
# Number of iterations of the gradient descent: 37112
# Correct classifications: 250
# Incorrect classifications: 53
# Accuracy of the logistic regression: 0.8250825082508251
# ----------------------------------------
# Number of iterations of the gradient descent: 43075
# Correct classifications: 257
# Incorrect classifications: 52
# Accuracy of the logistic regression: 0.8317152103559871
# ----------------------------------------
# Logistic regression mean: 0.8227086211506599
# Logistic regression standard deviation: 0.007328076094216765
# Logistic regression:
# Train-to-test split ratio: 0.11
# Number of iterations of the gradient descent: 30927
# Correct classifications: 259
# Incorrect classifications: 50
# Accuracy of the logistic regression: 0.8381877022653722
# ----------------------------------------
# Number of iterations of the gradient descent: 36056
# Correct classifications: 255
# Incorrect classifications: 51
# Accuracy of the logistic regression: 0.8333333333333334
# ----------------------------------------
# Number of iterations of the gradient descent: 29096
# Correct classifications: 231
# Incorrect classifications: 89
# Accuracy of the logistic regression: 0.721875
# ----------------------------------------
# Number of iterations of the gradient descent: 32192
# Correct classifications: 258
# Incorrect classifications: 41
# Accuracy of the logistic regression: 0.862876254180602
# ----------------------------------------
# Number of iterations of the gradient descent: 33468
# Correct classifications: 250
# Incorrect classifications: 59
# Accuracy of the logistic regression: 0.8090614886731392
# ----------------------------------------
# Logistic regression mean: 0.8130667556904893
# Logistic regression standard deviation: 0.04869242391954263
# Logistic regression:
# Train-to-test split ratio: 0.12
# Number of iterations of the gradient descent: 29404
# Correct classifications: 248
# Incorrect classifications: 61
# Accuracy of the logistic regression: 0.8025889967637541
# ----------------------------------------
# Number of iterations of the gradient descent: 49502
# Correct classifications: 259
# Incorrect classifications: 53
# Accuracy of the logistic regression: 0.8301282051282052
# ----------------------------------------
# Number of iterations of the gradient descent: 40125
# Correct classifications: 239
# Incorrect classifications: 75
# Accuracy of the logistic regression: 0.7611464968152867
# ----------------------------------------
# Number of iterations of the gradient descent: 44514
# Correct classifications: 262
# Incorrect classifications: 49
# Accuracy of the logistic regression: 0.842443729903537
# ----------------------------------------
# Number of iterations of the gradient descent: 22390
# Correct classifications: 250
# Incorrect classifications: 49
# Accuracy of the logistic regression: 0.8361204013377926
# ----------------------------------------
# Logistic regression mean: 0.8144855659897152
# Logistic regression standard deviation: 0.029936605849461707
# Logistic regression:
# Train-to-test split ratio: 0.13
# Number of iterations of the gradient descent: 29400
# Correct classifications: 257
# Incorrect classifications: 57
# Accuracy of the logistic regression: 0.8184713375796179
# ----------------------------------------
# Number of iterations of the gradient descent: 28188
# Correct classifications: 240
# Incorrect classifications: 63
# Accuracy of the logistic regression: 0.7920792079207921
# ----------------------------------------
# Number of iterations of the gradient descent: 25204
# Correct classifications: 259
# Incorrect classifications: 48
# Accuracy of the logistic regression: 0.8436482084690554
# ----------------------------------------
# Number of iterations of the gradient descent: 40635
# Correct classifications: 266
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8525641025641025
# ----------------------------------------
# Number of iterations of the gradient descent: 36336
# Correct classifications: 254
# Incorrect classifications: 50
# Accuracy of the logistic regression: 0.8355263157894737
# ----------------------------------------
# Logistic regression mean: 0.8284578344646084
# Logistic regression standard deviation: 0.021377360181126282
# Logistic regression:
# Train-to-test split ratio: 0.14
# Number of iterations of the gradient descent: 26616
# Correct classifications: 246
# Incorrect classifications: 59
# Accuracy of the logistic regression: 0.8065573770491803
# ----------------------------------------
# Number of iterations of the gradient descent: 27187
# Correct classifications: 250
# Incorrect classifications: 51
# Accuracy of the logistic regression: 0.8305647840531561
# ----------------------------------------
# Number of iterations of the gradient descent: 23535
# Correct classifications: 248
# Incorrect classifications: 55
# Accuracy of the logistic regression: 0.8184818481848185
# ----------------------------------------
# Number of iterations of the gradient descent: 44638
# Correct classifications: 243
# Incorrect classifications: 53
# Accuracy of the logistic regression: 0.8209459459459459
# ----------------------------------------
# Number of iterations of the gradient descent: 18958
# Correct classifications: 248
# Incorrect classifications: 58
# Accuracy of the logistic regression: 0.8104575163398693
# ----------------------------------------
# Logistic regression mean: 0.8174014943145942
# Logistic regression standard deviation: 0.008400192949840422
# Logistic regression:
# Train-to-test split ratio: 0.15
# Number of iterations of the gradient descent: 34567
# Correct classifications: 228
# Incorrect classifications: 75
# Accuracy of the logistic regression: 0.7524752475247525
# ----------------------------------------
# Number of iterations of the gradient descent: 37784
# Correct classifications: 249
# Incorrect classifications: 55
# Accuracy of the logistic regression: 0.819078947368421
# ----------------------------------------
# Number of iterations of the gradient descent: 40654
# Correct classifications: 247
# Incorrect classifications: 51
# Accuracy of the logistic regression: 0.8288590604026845
# ----------------------------------------
# Number of iterations of the gradient descent: 31212
# Correct classifications: 256
# Incorrect classifications: 54
# Accuracy of the logistic regression: 0.8258064516129032
# ----------------------------------------
# Number of iterations of the gradient descent: 26395
# Correct classifications: 243
# Incorrect classifications: 57
# Accuracy of the logistic regression: 0.81
# ----------------------------------------
# Logistic regression mean: 0.8072439413817524
# Logistic regression standard deviation: 0.02813913008244612
# Logistic regression:
# Train-to-test split ratio: 0.16
# Number of iterations of the gradient descent: 29532
# Correct classifications: 237
# Incorrect classifications: 51
# Accuracy of the logistic regression: 0.8229166666666666
# ----------------------------------------
# Number of iterations of the gradient descent: 31866
# Correct classifications: 241
# Incorrect classifications: 54
# Accuracy of the logistic regression: 0.8169491525423729
# ----------------------------------------
# Number of iterations of the gradient descent: 40804
# Correct classifications: 259
# Incorrect classifications: 43
# Accuracy of the logistic regression: 0.8576158940397351
# ----------------------------------------
# Number of iterations of the gradient descent: 42028
# Correct classifications: 252
# Incorrect classifications: 53
# Accuracy of the logistic regression: 0.8262295081967214
# ----------------------------------------
# Number of iterations of the gradient descent: 30171
# Correct classifications: 252
# Incorrect classifications: 54
# Accuracy of the logistic regression: 0.8235294117647058
# ----------------------------------------
# Logistic regression mean: 0.8294481266420404
# Logistic regression standard deviation: 0.014406235688898287
# Logistic regression:
# Train-to-test split ratio: 0.17
# Number of iterations of the gradient descent: 46225
# Correct classifications: 247
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8430034129692833
# ----------------------------------------
# Number of iterations of the gradient descent: 33606
# Correct classifications: 249
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.8556701030927835
# ----------------------------------------
# Number of iterations of the gradient descent: 32122
# Correct classifications: 244
# Incorrect classifications: 49
# Accuracy of the logistic regression: 0.8327645051194539
# ----------------------------------------
# Number of iterations of the gradient descent: 48960
# Correct classifications: 248
# Incorrect classifications: 47
# Accuracy of the logistic regression: 0.8406779661016949
# ----------------------------------------
# Number of iterations of the gradient descent: 28082
# Correct classifications: 238
# Incorrect classifications: 51
# Accuracy of the logistic regression: 0.8235294117647058
# ----------------------------------------
# Logistic regression mean: 0.8391290798095843
# Logistic regression standard deviation: 0.010722615460140484
# Logistic regression:
# Train-to-test split ratio: 0.18
# Number of iterations of the gradient descent: 35248
# Correct classifications: 242
# Incorrect classifications: 47
# Accuracy of the logistic regression: 0.8373702422145328
# ----------------------------------------
# Number of iterations of the gradient descent: 43879
# Correct classifications: 231
# Incorrect classifications: 50
# Accuracy of the logistic regression: 0.8220640569395018
# ----------------------------------------
# Number of iterations of the gradient descent: 43951
# Correct classifications: 235
# Incorrect classifications: 41
# Accuracy of the logistic regression: 0.8514492753623188
# ----------------------------------------
# Number of iterations of the gradient descent: 38822
# Correct classifications: 226
# Incorrect classifications: 62
# Accuracy of the logistic regression: 0.7847222222222222
# ----------------------------------------
# Number of iterations of the gradient descent: 49944
# Correct classifications: 235
# Incorrect classifications: 57
# Accuracy of the logistic regression: 0.8047945205479452
# ----------------------------------------
# Logistic regression mean: 0.8200800634573042
# Logistic regression standard deviation: 0.023540342928577547
# Logistic regression:
# Train-to-test split ratio: 0.19
# Number of iterations of the gradient descent: 48061
# Correct classifications: 243
# Incorrect classifications: 39
# Accuracy of the logistic regression: 0.8617021276595744
# ----------------------------------------
# Number of iterations of the gradient descent: 44550
# Correct classifications: 236
# Incorrect classifications: 60
# Accuracy of the logistic regression: 0.7972972972972973
# ----------------------------------------
# Number of iterations of the gradient descent: 46014
# Correct classifications: 230
# Incorrect classifications: 57
# Accuracy of the logistic regression: 0.8013937282229965
# ----------------------------------------
# Number of iterations of the gradient descent: 34836
# Correct classifications: 232
# Incorrect classifications: 51
# Accuracy of the logistic regression: 0.8197879858657244
# ----------------------------------------
# Number of iterations of the gradient descent: 48739
# Correct classifications: 243
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.8466898954703833
# ----------------------------------------
# Logistic regression mean: 0.8253742069031953
# Logistic regression standard deviation: 0.02517402821085189
# Logistic regression:
# Train-to-test split ratio: 0.2
# Number of iterations of the gradient descent: 50153
# Correct classifications: 236
# Incorrect classifications: 38
# Accuracy of the logistic regression: 0.8613138686131386
# ----------------------------------------
# Number of iterations of the gradient descent: 27422
# Correct classifications: 227
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8315018315018315
# ----------------------------------------
# Number of iterations of the gradient descent: 40842
# Correct classifications: 227
# Incorrect classifications: 47
# Accuracy of the logistic regression: 0.8284671532846716
# ----------------------------------------
# Number of iterations of the gradient descent: 35024
# Correct classifications: 220
# Incorrect classifications: 53
# Accuracy of the logistic regression: 0.8058608058608059
# ----------------------------------------
# Number of iterations of the gradient descent: 29386
# Correct classifications: 231
# Incorrect classifications: 51
# Accuracy of the logistic regression: 0.8191489361702128
# ----------------------------------------
# Logistic regression mean: 0.829258519086132
# Logistic regression standard deviation: 0.018345903055631593
# Logistic regression:
# Train-to-test split ratio: 0.21
# Number of iterations of the gradient descent: 42787
# Correct classifications: 232
# Incorrect classifications: 43
# Accuracy of the logistic regression: 0.8436363636363636
# ----------------------------------------
# Number of iterations of the gradient descent: 46349
# Correct classifications: 239
# Incorrect classifications: 41
# Accuracy of the logistic regression: 0.8535714285714285
# ----------------------------------------
# Number of iterations of the gradient descent: 45129
# Correct classifications: 222
# Incorrect classifications: 41
# Accuracy of the logistic regression: 0.844106463878327
# ----------------------------------------
# Number of iterations of the gradient descent: 27467
# Correct classifications: 239
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8385964912280702
# ----------------------------------------
# Number of iterations of the gradient descent: 58911
# Correct classifications: 242
# Incorrect classifications: 38
# Accuracy of the logistic regression: 0.8642857142857143
# ----------------------------------------
# Logistic regression mean: 0.8488392923199808
# Logistic regression standard deviation: 0.009114495830260047
# Logistic regression:
# Train-to-test split ratio: 0.22
# Number of iterations of the gradient descent: 41339
# Correct classifications: 243
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.8466898954703833
# ----------------------------------------
# Number of iterations of the gradient descent: 35895
# Correct classifications: 231
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.8461538461538461
# ----------------------------------------
# Number of iterations of the gradient descent: 61551
# Correct classifications: 216
# Incorrect classifications: 49
# Accuracy of the logistic regression: 0.8150943396226416
# ----------------------------------------
# Number of iterations of the gradient descent: 39724
# Correct classifications: 222
# Incorrect classifications: 53
# Accuracy of the logistic regression: 0.8072727272727273
# ----------------------------------------
# Number of iterations of the gradient descent: 27839
# Correct classifications: 234
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.841726618705036
# ----------------------------------------
# Logistic regression mean: 0.8313874854449267
# Logistic regression standard deviation: 0.016769585565739663
# Logistic regression:
# Train-to-test split ratio: 0.23
# Number of iterations of the gradient descent: 47251
# Correct classifications: 221
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.8403041825095057
# ----------------------------------------
# Number of iterations of the gradient descent: 53907
# Correct classifications: 218
# Incorrect classifications: 43
# Accuracy of the logistic regression: 0.8352490421455939
# ----------------------------------------
# Number of iterations of the gradient descent: 49064
# Correct classifications: 215
# Incorrect classifications: 48
# Accuracy of the logistic regression: 0.8174904942965779
# ----------------------------------------
# Number of iterations of the gradient descent: 35556
# Correct classifications: 231
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.8461538461538461
# ----------------------------------------
# Number of iterations of the gradient descent: 55389
# Correct classifications: 233
# Incorrect classifications: 37
# Accuracy of the logistic regression: 0.8629629629629629
# ----------------------------------------
# Logistic regression mean: 0.8404321056136974
# Logistic regression standard deviation: 0.01478902220407078
# Logistic regression:
# Train-to-test split ratio: 0.24
# Number of iterations of the gradient descent: 50622
# Correct classifications: 228
# Incorrect classifications: 43
# Accuracy of the logistic regression: 0.8413284132841329
# ----------------------------------------
# Number of iterations of the gradient descent: 36659
# Correct classifications: 228
# Incorrect classifications: 38
# Accuracy of the logistic regression: 0.8571428571428571
# ----------------------------------------
# Number of iterations of the gradient descent: 39128
# Correct classifications: 224
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.8421052631578947
# ----------------------------------------
# Number of iterations of the gradient descent: 42887
# Correct classifications: 228
# Incorrect classifications: 37
# Accuracy of the logistic regression: 0.8603773584905661
# ----------------------------------------
# Number of iterations of the gradient descent: 38251
# Correct classifications: 214
# Incorrect classifications: 40
# Accuracy of the logistic regression: 0.84251968503937
# ----------------------------------------
# Logistic regression mean: 0.8486947154229642
# Logistic regression standard deviation: 0.00829059148863183
# Logistic regression:
# Train-to-test split ratio: 0.25
# Number of iterations of the gradient descent: 53364
# Correct classifications: 217
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8250950570342205
# ----------------------------------------
# Number of iterations of the gradient descent: 32549
# Correct classifications: 222
# Incorrect classifications: 41
# Accuracy of the logistic regression: 0.844106463878327
# ----------------------------------------
# Number of iterations of the gradient descent: 38454
# Correct classifications: 233
# Incorrect classifications: 41
# Accuracy of the logistic regression: 0.8503649635036497
# ----------------------------------------
# Number of iterations of the gradient descent: 53861
# Correct classifications: 214
# Incorrect classifications: 41
# Accuracy of the logistic regression: 0.8392156862745098
# ----------------------------------------
# Number of iterations of the gradient descent: 34524
# Correct classifications: 222
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.8345864661654135
# ----------------------------------------
# Logistic regression mean: 0.838673727371224
# Logistic regression standard deviation: 0.008574139490329487
# Logistic regression:
# Train-to-test split ratio: 0.26
# Number of iterations of the gradient descent: 51909
# Correct classifications: 213
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8223938223938224
# ----------------------------------------
# Number of iterations of the gradient descent: 39501
# Correct classifications: 221
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.8339622641509434
# ----------------------------------------
# Number of iterations of the gradient descent: 42074
# Correct classifications: 226
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8308823529411765
# ----------------------------------------
# Number of iterations of the gradient descent: 47574
# Correct classifications: 224
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.875
# ----------------------------------------
# Number of iterations of the gradient descent: 46331
# Correct classifications: 233
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.8472727272727273
# ----------------------------------------
# Logistic regression mean: 0.841902233351734
# Logistic regression standard deviation: 0.01838131298538682
# Logistic regression:
# Train-to-test split ratio: 0.27
# Number of iterations of the gradient descent: 46311
# Correct classifications: 213
# Incorrect classifications: 53
# Accuracy of the logistic regression: 0.8007518796992481
# ----------------------------------------
# Number of iterations of the gradient descent: 46580
# Correct classifications: 211
# Incorrect classifications: 38
# Accuracy of the logistic regression: 0.8473895582329317
# ----------------------------------------
# Number of iterations of the gradient descent: 36400
# Correct classifications: 225
# Incorrect classifications: 36
# Accuracy of the logistic regression: 0.8620689655172413
# ----------------------------------------
# Number of iterations of the gradient descent: 38272
# Correct classifications: 213
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8223938223938224
# ----------------------------------------
# Number of iterations of the gradient descent: 29398
# Correct classifications: 213
# Incorrect classifications: 46
# Accuracy of the logistic regression: 0.8223938223938224
# ----------------------------------------
# Logistic regression mean: 0.8309996096474132
# Logistic regression standard deviation: 0.021433523295656356
# Logistic regression:
# Train-to-test split ratio: 0.28
# Number of iterations of the gradient descent: 42166
# Correct classifications: 198
# Incorrect classifications: 35
# Accuracy of the logistic regression: 0.8497854077253219
# ----------------------------------------
# Number of iterations of the gradient descent: 35845
# Correct classifications: 204
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.8225806451612904
# ----------------------------------------
# Number of iterations of the gradient descent: 48993
# Correct classifications: 209
# Incorrect classifications: 35
# Accuracy of the logistic regression: 0.8565573770491803
# ----------------------------------------
# Number of iterations of the gradient descent: 51532
# Correct classifications: 207
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.8625
# ----------------------------------------
# Number of iterations of the gradient descent: 47558
# Correct classifications: 213
# Incorrect classifications: 37
# Accuracy of the logistic regression: 0.852
# ----------------------------------------
# Logistic regression mean: 0.8486846859871585
# Logistic regression standard deviation: 0.013758386595954141
# Logistic regression:
# Train-to-test split ratio: 0.29
# Number of iterations of the gradient descent: 46269
# Correct classifications: 194
# Incorrect classifications: 39
# Accuracy of the logistic regression: 0.8326180257510729
# ----------------------------------------
# Number of iterations of the gradient descent: 38041
# Correct classifications: 212
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.8617886178861789
# ----------------------------------------
# Number of iterations of the gradient descent: 41301
# Correct classifications: 203
# Incorrect classifications: 40
# Accuracy of the logistic regression: 0.8353909465020576
# ----------------------------------------
# Number of iterations of the gradient descent: 34918
# Correct classifications: 205
# Incorrect classifications: 40
# Accuracy of the logistic regression: 0.8367346938775511
# ----------------------------------------
# Number of iterations of the gradient descent: 40513
# Correct classifications: 199
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.8257261410788381
# ----------------------------------------
# Logistic regression mean: 0.8384516850191396
# Logistic regression standard deviation: 0.012271101527763393
# Logistic regression:
# Train-to-test split ratio: 0.3
# Number of iterations of the gradient descent: 36799
# Correct classifications: 194
# Incorrect classifications: 40
# Accuracy of the logistic regression: 0.8290598290598291
# ----------------------------------------
# Number of iterations of the gradient descent: 44095
# Correct classifications: 203
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.8218623481781376
# ----------------------------------------
# Number of iterations of the gradient descent: 52546
# Correct classifications: 208
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.8630705394190872
# ----------------------------------------
# Number of iterations of the gradient descent: 33203
# Correct classifications: 208
# Incorrect classifications: 45
# Accuracy of the logistic regression: 0.8221343873517787
# ----------------------------------------
# Number of iterations of the gradient descent: 42562
# Correct classifications: 199
# Incorrect classifications: 35
# Accuracy of the logistic regression: 0.8504273504273504
# ----------------------------------------
# Logistic regression mean: 0.8373108908872366
# Logistic regression standard deviation: 0.016569035916602005
# Logistic regression:
# Train-to-test split ratio: 0.31
# Number of iterations of the gradient descent: 40409
# Correct classifications: 200
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.8264462809917356
# ----------------------------------------
# Number of iterations of the gradient descent: 37257
# Correct classifications: 205
# Incorrect classifications: 37
# Accuracy of the logistic regression: 0.8471074380165289
# ----------------------------------------
# Number of iterations of the gradient descent: 48743
# Correct classifications: 202
# Incorrect classifications: 28
# Accuracy of the logistic regression: 0.8782608695652174
# ----------------------------------------
# Number of iterations of the gradient descent: 49872
# Correct classifications: 202
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.8595744680851064
# ----------------------------------------
# Number of iterations of the gradient descent: 42607
# Correct classifications: 196
# Incorrect classifications: 40
# Accuracy of the logistic regression: 0.8305084745762712
# ----------------------------------------
# Logistic regression mean: 0.8483795062469719
# Logistic regression standard deviation: 0.019080258619679685
# Logistic regression:
# Train-to-test split ratio: 0.32
# Number of iterations of the gradient descent: 44380
# Correct classifications: 202
# Incorrect classifications: 45
# Accuracy of the logistic regression: 0.8178137651821862
# ----------------------------------------
# Number of iterations of the gradient descent: 48129
# Correct classifications: 208
# Incorrect classifications: 36
# Accuracy of the logistic regression: 0.8524590163934426
# ----------------------------------------
# Number of iterations of the gradient descent: 49167
# Correct classifications: 203
# Incorrect classifications: 31
# Accuracy of the logistic regression: 0.8675213675213675
# ----------------------------------------
# Number of iterations of the gradient descent: 55005
# Correct classifications: 210
# Incorrect classifications: 28
# Accuracy of the logistic regression: 0.8823529411764706
# ----------------------------------------
# Number of iterations of the gradient descent: 38799
# Correct classifications: 197
# Incorrect classifications: 47
# Accuracy of the logistic regression: 0.8073770491803278
# ----------------------------------------
# Logistic regression mean: 0.845504827890759
# Logistic regression standard deviation: 0.02867540643504593
# Logistic regression:
# Train-to-test split ratio: 0.33
# Number of iterations of the gradient descent: 50330
# Correct classifications: 203
# Incorrect classifications: 37
# Accuracy of the logistic regression: 0.8458333333333333
# ----------------------------------------
# Number of iterations of the gradient descent: 45283
# Correct classifications: 198
# Incorrect classifications: 31
# Accuracy of the logistic regression: 0.8646288209606987
# ----------------------------------------
# Number of iterations of the gradient descent: 44089
# Correct classifications: 196
# Incorrect classifications: 37
# Accuracy of the logistic regression: 0.8412017167381974
# ----------------------------------------
# Number of iterations of the gradient descent: 53059
# Correct classifications: 202
# Incorrect classifications: 28
# Accuracy of the logistic regression: 0.8782608695652174
# ----------------------------------------
# Number of iterations of the gradient descent: 51083
# Correct classifications: 206
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.8583333333333333
# ----------------------------------------
# Logistic regression mean: 0.8576516147861561
# Logistic regression standard deviation: 0.013297807721683092
# Logistic regression:
# Train-to-test split ratio: 0.34
# Number of iterations of the gradient descent: 52471
# Correct classifications: 203
# Incorrect classifications: 24
# Accuracy of the logistic regression: 0.8942731277533039
# ----------------------------------------
# Number of iterations of the gradient descent: 40565
# Correct classifications: 202
# Incorrect classifications: 25
# Accuracy of the logistic regression: 0.8898678414096917
# ----------------------------------------
# Number of iterations of the gradient descent: 49304
# Correct classifications: 202
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.8595744680851064
# ----------------------------------------
# Number of iterations of the gradient descent: 45426
# Correct classifications: 197
# Incorrect classifications: 39
# Accuracy of the logistic regression: 0.8347457627118644
# ----------------------------------------
# Number of iterations of the gradient descent: 34841
# Correct classifications: 192
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.8135593220338984
# ----------------------------------------
# Logistic regression mean: 0.8584041043987728
# Logistic regression standard deviation: 0.03114063252724939
# Logistic regression:
# Train-to-test split ratio: 0.35000000000000003
# Number of iterations of the gradient descent: 40275
# Correct classifications: 189
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.863013698630137
# ----------------------------------------
# Number of iterations of the gradient descent: 44313
# Correct classifications: 193
# Incorrect classifications: 31
# Accuracy of the logistic regression: 0.8616071428571429
# ----------------------------------------
# Number of iterations of the gradient descent: 40164
# Correct classifications: 182
# Incorrect classifications: 36
# Accuracy of the logistic regression: 0.8348623853211009
# ----------------------------------------
# Number of iterations of the gradient descent: 26726
# Correct classifications: 183
# Incorrect classifications: 44
# Accuracy of the logistic regression: 0.8061674008810573
# ----------------------------------------
# Number of iterations of the gradient descent: 32943
# Correct classifications: 190
# Incorrect classifications: 45
# Accuracy of the logistic regression: 0.8085106382978723
# ----------------------------------------
# Logistic regression mean: 0.834832253197462
# Logistic regression standard deviation: 0.02459914901028649
# Logistic regression:
# Train-to-test split ratio: 0.36
# Number of iterations of the gradient descent: 42590
# Correct classifications: 204
# Incorrect classifications: 35
# Accuracy of the logistic regression: 0.8535564853556485
# ----------------------------------------
# Number of iterations of the gradient descent: 32641
# Correct classifications: 190
# Incorrect classifications: 35
# Accuracy of the logistic regression: 0.8444444444444444
# ----------------------------------------
# Number of iterations of the gradient descent: 53113
# Correct classifications: 193
# Incorrect classifications: 33
# Accuracy of the logistic regression: 0.8539823008849557
# ----------------------------------------
# Number of iterations of the gradient descent: 52437
# Correct classifications: 194
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.8660714285714286
# ----------------------------------------
# Number of iterations of the gradient descent: 55072
# Correct classifications: 197
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.8528138528138528
# ----------------------------------------
# Logistic regression mean: 0.8541737024140661
# Logistic regression standard deviation: 0.006906245444998058
# Logistic regression:
# Train-to-test split ratio: 0.37
# Number of iterations of the gradient descent: 46536
# Correct classifications: 187
# Incorrect classifications: 31
# Accuracy of the logistic regression: 0.8577981651376146
# ----------------------------------------
# Number of iterations of the gradient descent: 47345
# Correct classifications: 186
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.8611111111111112
# ----------------------------------------
# Number of iterations of the gradient descent: 44165
# Correct classifications: 195
# Incorrect classifications: 24
# Accuracy of the logistic regression: 0.8904109589041096
# ----------------------------------------
# Number of iterations of the gradient descent: 44799
# Correct classifications: 194
# Incorrect classifications: 27
# Accuracy of the logistic regression: 0.8778280542986425
# ----------------------------------------
# Number of iterations of the gradient descent: 42280
# Correct classifications: 188
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.8623853211009175
# ----------------------------------------
# Logistic regression mean: 0.869906722110479
# Logistic regression standard deviation: 0.01235898562252134
# Logistic regression:
# Train-to-test split ratio: 0.38
# Number of iterations of the gradient descent: 42509
# Correct classifications: 183
# Incorrect classifications: 28
# Accuracy of the logistic regression: 0.8672985781990521
# ----------------------------------------
# Number of iterations of the gradient descent: 40392
# Correct classifications: 181
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.8418604651162791
# ----------------------------------------
# Number of iterations of the gradient descent: 50191
# Correct classifications: 202
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.8706896551724138
# ----------------------------------------
# Number of iterations of the gradient descent: 35409
# Correct classifications: 189
# Incorrect classifications: 36
# Accuracy of the logistic regression: 0.84
# ----------------------------------------
# Number of iterations of the gradient descent: 45360
# Correct classifications: 166
# Incorrect classifications: 42
# Accuracy of the logistic regression: 0.7980769230769231
# ----------------------------------------
# Logistic regression mean: 0.8435851243129336
# Logistic regression standard deviation: 0.02601463985429205
# Logistic regression:
# Train-to-test split ratio: 0.39
# Number of iterations of the gradient descent: 47154
# Correct classifications: 194
# Incorrect classifications: 24
# Accuracy of the logistic regression: 0.8899082568807339
# ----------------------------------------
# Number of iterations of the gradient descent: 38462
# Correct classifications: 181
# Incorrect classifications: 30
# Accuracy of the logistic regression: 0.8578199052132701
# ----------------------------------------
# Number of iterations of the gradient descent: 39182
# Correct classifications: 198
# Incorrect classifications: 36
# Accuracy of the logistic regression: 0.8461538461538461
# ----------------------------------------
# Number of iterations of the gradient descent: 38324
# Correct classifications: 177
# Incorrect classifications: 34
# Accuracy of the logistic regression: 0.8388625592417062
# ----------------------------------------
# Number of iterations of the gradient descent: 42199
# Correct classifications: 171
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.8423645320197044
# ----------------------------------------
# Logistic regression mean: 0.8550218199018522
# Logistic regression standard deviation: 0.018573434612375244
# Logistic regression:
# Train-to-test split ratio: 0.4
# Number of iterations of the gradient descent: 37596
# Correct classifications: 175
# Incorrect classifications: 31
# Accuracy of the logistic regression: 0.8495145631067961
# ----------------------------------------
# Number of iterations of the gradient descent: 44943
# Correct classifications: 178
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.8476190476190476
# ----------------------------------------
# Number of iterations of the gradient descent: 47452
# Correct classifications: 187
# Incorrect classifications: 39
# Accuracy of the logistic regression: 0.827433628318584
# ----------------------------------------
# Number of iterations of the gradient descent: 43046
# Correct classifications: 171
# Incorrect classifications: 32
# Accuracy of the logistic regression: 0.8423645320197044
# ----------------------------------------
# Number of iterations of the gradient descent: 41569
# Correct classifications: 183
# Incorrect classifications: 35
# Accuracy of the logistic regression: 0.8394495412844036
# ----------------------------------------
# Logistic regression mean: 0.841276262469707
# Logistic regression standard deviation: 0.007800516418569757
# Logistic regression:
# Train-to-test split ratio: 0.41000000000000003
# Number of iterations of the gradient descent: 49596
# Correct classifications: 179
# ...
# Correct classifications: 48
# Incorrect classifications: 4
# Accuracy of the logistic regression: 0.9230769230769231
# ----------------------------------------
# Number of iterations of the gradient descent: 28846
# Correct classifications: 34
# Incorrect classifications: 9
# Accuracy of the logistic regression: 0.7906976744186046
# ----------------------------------------
# Number of iterations of the gradient descent: 37477
# Correct classifications: 42
# Incorrect classifications: 7
# Accuracy of the logistic regression: 0.8571428571428571
# ----------------------------------------
# Number of iterations of the gradient descent: 37427
# Correct classifications: 37
# Incorrect classifications: 8
# Accuracy of the logistic regression: 0.8222222222222222
# ----------------------------------------
# Logistic regression mean: 0.8577946020387881
# Logistic regression standard deviation: 0.04790937944059865
# Logistic regression:
# Train-to-test split ratio: 0.87
# Number of iterations of the gradient descent: 35021
# Correct classifications: 38
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.8837209302325582
# ----------------------------------------
# Number of iterations of the gradient descent: 34521
# Correct classifications: 46
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.9387755102040817
# ----------------------------------------
# Number of iterations of the gradient descent: 32075
# Correct classifications: 34
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.918918918918919
# ----------------------------------------
# Number of iterations of the gradient descent: 36458
# Correct classifications: 34
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.918918918918919
# ----------------------------------------
# Number of iterations of the gradient descent: 33177
# Correct classifications: 42
# Incorrect classifications: 7
# Accuracy of the logistic regression: 0.8571428571428571
# ----------------------------------------
# Logistic regression mean: 0.903495427083467
# Logistic regression standard deviation: 0.0291891895454455
# Logistic regression:
# Train-to-test split ratio: 0.88
# Number of iterations of the gradient descent: 30773
# Correct classifications: 34
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.8717948717948718
# ----------------------------------------
# Number of iterations of the gradient descent: 32284
# Correct classifications: 37
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.8809523809523809
# ----------------------------------------
# Number of iterations of the gradient descent: 38213
# Correct classifications: 34
# Incorrect classifications: 4
# Accuracy of the logistic regression: 0.8947368421052632
# ----------------------------------------
# Number of iterations of the gradient descent: 36054
# Correct classifications: 37
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.925
# ----------------------------------------
# Number of iterations of the gradient descent: 33583
# Correct classifications: 40
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.9523809523809523
# ----------------------------------------
# Logistic regression mean: 0.9049730094466938
# Logistic regression standard deviation: 0.029769621888854902
# Logistic regression:
# Train-to-test split ratio: 0.89
# Number of iterations of the gradient descent: 31231
# Correct classifications: 36
# Incorrect classifications: 6
# Accuracy of the logistic regression: 0.8571428571428571
# ----------------------------------------
# Number of iterations of the gradient descent: 32958
# Correct classifications: 44
# Incorrect classifications: 6
# Accuracy of the logistic regression: 0.88
# ----------------------------------------
# Number of iterations of the gradient descent: 38956
# Correct classifications: 34
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.8717948717948718
# ----------------------------------------
# Number of iterations of the gradient descent: 37175
# Correct classifications: 32
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.9142857142857143
# ----------------------------------------
# Number of iterations of the gradient descent: 36300
# Correct classifications: 26
# Incorrect classifications: 4
# Accuracy of the logistic regression: 0.8666666666666667
# ----------------------------------------
# Logistic regression mean: 0.877978021978022
# Logistic regression standard deviation: 0.01960927900105981
# Logistic regression:
# Train-to-test split ratio: 0.9
# Number of iterations of the gradient descent: 32246
# Correct classifications: 32
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9696969696969697
# ----------------------------------------
# Number of iterations of the gradient descent: 38036
# Correct classifications: 40
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.9302325581395349
# ----------------------------------------
# Number of iterations of the gradient descent: 33605
# Correct classifications: 34
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9714285714285714
# ----------------------------------------
# Number of iterations of the gradient descent: 35928
# Correct classifications: 30
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.8571428571428571
# ----------------------------------------
# Number of iterations of the gradient descent: 30527
# Correct classifications: 35
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.875
# ----------------------------------------
# Logistic regression mean: 0.9207001912815865
# Logistic regression standard deviation: 0.04731376347604021
# Logistic regression:
# Train-to-test split ratio: 0.91
# Number of iterations of the gradient descent: 31865
# Correct classifications: 35
# Incorrect classifications: 6
# Accuracy of the logistic regression: 0.8536585365853658
# ----------------------------------------
# Number of iterations of the gradient descent: 32136
# Correct classifications: 22
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.8148148148148148
# ----------------------------------------
# Number of iterations of the gradient descent: 33370
# Correct classifications: 29
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.9354838709677419
# ----------------------------------------
# Number of iterations of the gradient descent: 32306
# Correct classifications: 22
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.8148148148148148
# ----------------------------------------
# Number of iterations of the gradient descent: 32910
# Correct classifications: 30
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.8571428571428571
# ----------------------------------------
# Logistic regression mean: 0.8551829788651188
# Logistic regression standard deviation: 0.04407624225632099
# Logistic regression:
# Train-to-test split ratio: 0.92
# Number of iterations of the gradient descent: 30855
# Correct classifications: 26
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.896551724137931
# ----------------------------------------
# Number of iterations of the gradient descent: 34222
# Correct classifications: 22
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.9166666666666666
# ----------------------------------------
# Number of iterations of the gradient descent: 35437
# Correct classifications: 28
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9655172413793104
# ----------------------------------------
# Number of iterations of the gradient descent: 31635
# Correct classifications: 28
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.9333333333333333
# ----------------------------------------
# Number of iterations of the gradient descent: 34596
# Correct classifications: 37
# Incorrect classifications: 4
# Accuracy of the logistic regression: 0.9024390243902439
# ----------------------------------------
# Logistic regression mean: 0.9229015979814971
# Logistic regression standard deviation: 0.02480653664948128
# Logistic regression:
# Train-to-test split ratio: 0.93
# Number of iterations of the gradient descent: 36174
# Correct classifications: 25
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.8928571428571429
# ----------------------------------------
# Number of iterations of the gradient descent: 37346
# Correct classifications: 25
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.8928571428571429
# ----------------------------------------
# Number of iterations of the gradient descent: 28614
# Correct classifications: 16
# Incorrect classifications: 5
# Accuracy of the logistic regression: 0.7619047619047619
# ----------------------------------------
# Number of iterations of the gradient descent: 29820
# Correct classifications: 19
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.8636363636363636
# ----------------------------------------
# Number of iterations of the gradient descent: 33831
# Correct classifications: 24
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.8822510822510822
# Logistic regression standard deviation: 0.07605199437779996
# Logistic regression:
# Train-to-test split ratio: 0.9400000000000001
# Number of iterations of the gradient descent: 31585
# Correct classifications: 19
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.95
# ----------------------------------------
# Number of iterations of the gradient descent: 33443
# Correct classifications: 10
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9090909090909091
# ----------------------------------------
# Number of iterations of the gradient descent: 34841
# Correct classifications: 24
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.9230769230769231
# ----------------------------------------
# Number of iterations of the gradient descent: 33202
# Correct classifications: 15
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.8823529411764706
# ----------------------------------------
# Number of iterations of the gradient descent: 32156
# Correct classifications: 13
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.8125
# ----------------------------------------
# Logistic regression mean: 0.8954041546688604
# Logistic regression standard deviation: 0.04685562659997137
# Logistic regression:
# Train-to-test split ratio: 0.9500000000000001
# Number of iterations of the gradient descent: 33944
# Correct classifications: 23
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.8846153846153846
# ----------------------------------------
# Number of iterations of the gradient descent: 38160
# Correct classifications: 11
# Incorrect classifications: 4
# Accuracy of the logistic regression: 0.7333333333333333
# ----------------------------------------
# Number of iterations of the gradient descent: 36064
# Correct classifications: 12
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.8
# ----------------------------------------
# Number of iterations of the gradient descent: 30795
# Correct classifications: 7
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.7
# ----------------------------------------
# Number of iterations of the gradient descent: 33379
# Correct classifications: 16
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.8235897435897437
# Logistic regression standard deviation: 0.10846366003865505
# Logistic regression:
# Train-to-test split ratio: 0.96
# Number of iterations of the gradient descent: 33462
# Correct classifications: 11
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Number of iterations of the gradient descent: 32397
# Correct classifications: 10
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9090909090909091
# ----------------------------------------
# Number of iterations of the gradient descent: 31128
# Correct classifications: 15
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.8823529411764706
# ----------------------------------------
# Number of iterations of the gradient descent: 32880
# Correct classifications: 9
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9
# ----------------------------------------
# Number of iterations of the gradient descent: 32335
# Correct classifications: 14
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.9333333333333333
# ----------------------------------------
# Logistic regression mean: 0.9249554367201427
# Logistic regression standard deviation: 0.04096658471209477
# Logistic regression:
# Train-to-test split ratio: 0.97
# Number of iterations of the gradient descent: 37266
# Correct classifications: 16
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.8421052631578947
# ----------------------------------------
# Number of iterations of the gradient descent: 34214
# Correct classifications: 12
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.8571428571428571
# ----------------------------------------
# Number of iterations of the gradient descent: 33762
# Correct classifications: 7
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Number of iterations of the gradient descent: 32869
# Correct classifications: 7
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.875
# ----------------------------------------
# Number of iterations of the gradient descent: 32742
# Correct classifications: 5
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.625
# ----------------------------------------
# Logistic regression mean: 0.8398496240601503
# Logistic regression standard deviation: 0.1211182864966046
# Logistic regression:
# Train-to-test split ratio: 0.98
# Number of iterations of the gradient descent: 32656
# Correct classifications: 6
# Incorrect classifications: 2
# Accuracy of the logistic regression: 0.75
# ----------------------------------------
# Number of iterations of the gradient descent: 33992
# Correct classifications: 7
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Number of iterations of the gradient descent: 33293
# Correct classifications: 3
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Number of iterations of the gradient descent: 33389
# Correct classifications: 8
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Number of iterations of the gradient descent: 33338
# Correct classifications: 4
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Logistic regression mean: 0.95
# Logistic regression standard deviation: 0.09999999999999999
# Logistic regression:
# Train-to-test split ratio: 0.99
# Number of iterations of the gradient descent: 33189
# Correct classifications: 3
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Number of iterations of the gradient descent: 34109
# Correct classifications: 3
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.75
# ----------------------------------------
# Number of iterations of the gradient descent: 33567
# Correct classifications: 4
# Incorrect classifications: 0
# Accuracy of the logistic regression: 1.0
# ----------------------------------------
# Number of iterations of the gradient descent: 34205
# Correct classifications: 3
# Incorrect classifications: 3
# Accuracy of the logistic regression: 0.5
# ----------------------------------------
# Number of iterations of the gradient descent: 30793
# Correct classifications: 5
# Incorrect classifications: 1
# Accuracy of the logistic regression: 0.8333333333333334
# ----------------------------------------
# Logistic regression mean: 0.8166666666666667
# Logistic regression standard deviation: 0.1855921454276674

# %% [markdown]
# Similarly, we obtain the error as $error = 1 - \mu$.

# %%
error = []
for m in mus:
    error.append(1 - m)

# %%
#plt.plot(n_iterations, mus)
plt.xlabel('Train/test split ratio')
plt.ylabel('Error')
#plt.xscale(value = 'log')
plt.errorbar(split_ratio, error, stds, color = 'red', ecolor = 'blue', linewidth = 5)
plt.grid()
plt.title('Accuracy of logistic regression depending on the test/train ration\n with the mean in red and the standard deviation in blue')
plt.show()

# %% [markdown]
# Note that the error assymptotically goes down when we use more data for trainging until the very end where the test data becomes insufficient.
